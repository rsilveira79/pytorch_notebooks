# %% [markdown]
# # BoW Classifier for sentiment classification

# %%
import re
import pandas as pd
import numpy as np

## Pytorch Imports
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data
import torch.nn.functional as F
import torch.optim as optim

## NLP Libraries
import spacy
from sklearn.model_selection import train_test_split
from nltk import download
import gensim
from nltk.corpus import stopwords

spacy_en = spacy.load('en')
download('stopwords')
# Out:
# Using TensorFlow backend.
# /Users/rsilvei/Envs/nlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# [nltk_data] Error loading stopwords: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# False

# %% [markdown]
# ## 1. Classifier architecture

# %% [markdown]
# ## 2. Dataset
# - more information here: https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews
# - 0 - negative
# - 1 - positive

# %%
train = pd.read_pickle('train.pkl')
train.drop(labels='phrase_preprocessed', inplace=True,axis=1)
train.head()
# Out:
#                                               phrase sentiment  \
# 0  A series of escapades demonstrating the adage ...         1
# 1  This quiet , introspective and entertaining in...         4
# 2  Even fans of Ismail Merchant 's work , I suspe...         1
# 3  A positively thrilling combination of ethnogra...         3
# 4  Aggressive self-glorification and a manipulati...         1
#
#   sentiment_simple
# 0              NEG
# 1              POS
# 2              NEG
# 3              POS
# 4              NEG

# %%
test = pd.read_pickle('test.pkl')
test.drop(labels='phrase_preprocessed', inplace=True,axis=1)
test.head()
# Out:
#                                               phrase
# 0  An intermittently pleasing but mostly routine ...
# 1  Kidman is really the only thing that 's worth ...
# 2  Once you get into its rhythm ... the movie bec...
# 3  I kept wishing I was watching a documentary ab...
# 4  Kinnear does n't aim for our sympathy , but ra...

# %% [markdown]
# ## 3. Preprocessing

# %%
def transformText(text, do_stop=False, do_stem=False):
    
    stops = set(stopwords.words("english"))
    
    # Convert text to lower
    text = text.lower()
    
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    # Removing all the stopwords
    
    if (do_stop==True):
        filtered_words = [word for word in text.split() if word not in stops]
    else:
        filtered_words = [word for word in text.split()]

    # Removing all the tokens with lesser than 3 characters
    filtered_words = gensim.corpora.textcorpus.remove_short(filtered_words, minsize=3)
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # Strip all the numerics
    text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    if (do_stem==True):
        # Stemming
        text = gensim.parsing.preprocessing.stem_text(text)
    return text

# %%
train['phrase_preprocessed']=train['phrase'].apply(lambda x: transformText(x,do_stop=False, do_stem=False))
train.head()
# Out:
#                                               phrase sentiment  \
# 0  A series of escapades demonstrating the adage ...         1
# 1  This quiet , introspective and entertaining in...         4
# 2  Even fans of Ismail Merchant 's work , I suspe...         1
# 3  A positively thrilling combination of ethnogra...         3
# 4  Aggressive self-glorification and a manipulati...         1
#
#   sentiment_simple                                phrase_preprocessed
# 0              NEG  series escapades demonstrating the adage that ...
# 1              POS  this quiet introspective and entertaining inde...
# 2              NEG  even fans ismail merchant work suspect would h...
# 3              POS  positively thrilling combination ethnography a...
# 4              NEG  aggressive self glorification and manipulative...

# %%
test['phrase_preprocessed']=test['phrase'].apply(lambda x: transformText(x,do_stop=False, do_stem=False))
test.head()
# Out:
#                                               phrase  \
# 0  An intermittently pleasing but mostly routine ...
# 1  Kidman is really the only thing that 's worth ...
# 2  Once you get into its rhythm ... the movie bec...
# 3  I kept wishing I was watching a documentary ab...
# 4  Kinnear does n't aim for our sympathy , but ra...
#
#                                  phrase_preprocessed
# 0  intermittently pleasing but mostly routine effort
# 1  kidman really the only thing that worth watchi...
# 2  once you get into its rhythm the movie becomes...
# 3  kept wishing was watching documentary about th...
# 4  kinnear does n t aim for our sympathy but rath...

# %% [markdown]
# ## 4. Train/Test split, Vocab

# %%
test_size = 0.2

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train['phrase_preprocessed'],
                                                      train['sentiment_simple'], 
                                                      test_size=0.2)

# %%
x_test=test['phrase_preprocessed']
x_test[0:5]
# Out:
# 0    intermittently pleasing but mostly routine effort
# 1    kidman really the only thing that worth watchi...
# 2    once you get into its rhythm the movie becomes...
# 3    kept wishing was watching documentary about th...
# 4    kinnear does n t aim for our sympathy but rath...
# Name: phrase_preprocessed, dtype: object

# %%
## Build Vocabulary
word_to_ix = {}
for sent in list(x_train) + list(x_valid) + list(x_test):
    for word in sent.split():
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

# %%
word_to_ix
# Out:
# {'starts': 0,
#  'intense': 1,
#  'political': 2,
#  'and': 3,
#  'psychological': 4,
#  'thriller': 5,
#  'but': 6,
#  'sabotaged': 7,
#  'ticking': 8,
#  'time': 9,
#  'bombs': 10,
#  'other': 11,
#  'hollywood': 12,
#  'action': 13,
#  'cliches': 14,
#  'while': 15,
#  'kids': 16,
#  'will': 17,
#  'probably': 18,
#  'eat': 19,
#  'the': 20,
#  'whole': 21,
#  'thing': 22,
#  'most': 23,
#  'adults': 24,
#  'way': 25,
#  'ahead': 26,
#  'plot': 27,
#  'hoot': 28,
#  'watching': 29,
#  'rock': 30,
#  'chomp': 31,
#  'jumbo': 32,
#  'ants': 33,
#  'pull': 34,
#  'arrow': 35,
#  'out': 36,
#  'his': 37,
#  'back': 38,
#  'leap': 39,
#  'unscathed': 40,
#  'through': 41,
#  'raging': 42,
#  'fire': 43,
#  'how': 44,
#  'washed': 45,
#  'despite': 46,
#  'all': 47,
#  'that': 48,
#  'project': 49,
#  'prime': 50,
#  'mystery': 51,
#  'laggard': 52,
#  'drama': 53,
#  'wending': 54,
#  'its': 55,
#  'uninspired': 56,
#  'philosophical': 57,
#  'epiphany': 58,
#  'feels': 59,
#  'like': 60,
#  'cold': 61,
#  'old': 62,
#  'man': 63,
#  'going': 64,
#  'motions': 65,
#  'path': 66,
#  'may': 67,
#  'familiar': 68,
#  'first': 69,
#  'director': 70,
#  'denzel': 71,
#  'washington': 72,
#  'top': 73,
#  'notch': 74,
#  'cast': 75,
#  'manage': 76,
#  'keep': 77,
#  'things': 78,
#  'interesting': 79,
#  'empty': 80,
#  'shell': 81,
#  'epic': 82,
#  'rather': 83,
#  'than': 84,
#  'real': 85,
#  'deal': 86,
#  'reeboir': 87,
#  'varies': 88,
#  'between': 89,
#  'sweet': 90,
#  'smile': 91,
#  'angry': 92,
#  'bark': 93,
#  'said': 94,
#  'attempts': 95,
#  'wear': 96,
#  'down': 97,
#  'possible': 98,
#  'pupils': 99,
#  'repetition': 100,
#  'cloaks': 101,
#  'anti': 102,
#  'feminist': 103,
#  'equation': 104,
#  'lrb': 105,
#  'career': 106,
#  'misery': 107,
#  'rrb': 108,
#  'tiresome': 109,
#  'romantic': 110,
#  'comedy': 111,
#  'duds': 112,
#  'dangerous': 113,
#  'lives': 114,
#  'altar': 115,
#  'boys': 116,
#  'take': 117,
#  'adolescence': 118,
#  'painfully': 119,
#  'true': 120,
#  'anyone': 121,
#  'who': 122,
#  'welcomes': 123,
#  'dash': 124,
#  'avant': 125,
#  'garde': 126,
#  'fused': 127,
#  'with': 128,
#  'their': 129,
#  'humor': 130,
#  'should': 131,
#  'pleasure': 132,
#  'this': 133,
#  'crazed': 134,
#  'joyous': 135,
#  'romp': 136,
#  'film': 137,
#  'usually': 138,
#  'bad': 139,
#  'sign': 140,
#  'when': 141,
#  'directors': 142,
#  'abandon': 143,
#  'scripts': 144,
#  'where': 145,
#  'moment': 146,
#  'takes': 147,
#  'them': 148,
#  'olympia': 149,
#  'wash': 150,
#  'based': 151,
#  'filmmakers': 152,
#  'anne': 153,
#  'marcken': 154,
#  'marilyn': 155,
#  'freeman': 156,
#  'did': 157,
#  'just': 158,
#  'what': 159,
#  'makes': 160,
#  'nothing': 161,
#  'can': 162,
#  'detract': 163,
#  'from': 164,
#  'affection': 165,
#  'moral': 166,
#  'favorite': 167,
#  'friends': 168,
#  'thick': 169,
#  'thin': 170,
#  'you': 171,
#  'think': 172,
#  'every': 173,
#  'angle': 174,
#  'has': 175,
#  'been': 176,
#  'exhausted': 177,
#  'documentarians': 178,
#  'another': 179,
#  'new': 180,
#  'emerges': 181,
#  'yet': 182,
#  'remarkable': 183,
#  'shockingly': 184,
#  'little': 185,
#  'known': 186,
#  'perspective': 187,
#  'road': 188,
#  'trip': 189,
#  'get': 190,
#  'thinking': 191,
#  'are': 192,
#  'there': 193,
#  'beautiful': 194,
#  'paean': 195,
#  'long': 196,
#  'past': 197,
#  'graceful': 198,
#  'moving': 199,
#  'tribute': 200,
#  'courage': 201,
#  'york': 202,
#  'finest': 203,
#  'nicely': 204,
#  'understated': 205,
#  'expression': 206,
#  'grief': 207,
#  'shared': 208,
#  'nation': 209,
#  'sacrifice': 210,
#  'tense': 211,
#  'terrific': 212,
#  'sweaty': 213,
#  'palmed': 214,
#  'fun': 215,
#  'hugely': 216,
#  'accomplished': 217,
#  'slice': 218,
#  'hitchcockian': 219,
#  'suspense': 220,
#  'hypnotic': 221,
#  'portrait': 222,
#  'sad': 223,
#  'compulsive': 224,
#  'life': 225,
#  'trashy': 226,
#  'teen': 227,
#  'sleaze': 228,
#  'equivalent': 229,
#  'showgirls': 230,
#  'more': 231,
#  'enjoyable': 232,
#  'expected': 233,
#  'though': 234,
#  'because': 235,
#  'laughs': 236,
#  'come': 237,
#  'fairly': 238,
#  'basic': 239,
#  'comedic': 240,
#  'constructs': 241,
#  'different': 242,
#  'apple': 243,
#  'striking': 244,
#  'only': 245,
#  'encourage': 246,
#  'see': 247,
#  'samira': 248,
#  'makhmalbaf': 249,
#  'very': 250,
#  'distinctive': 251,
#  'sensibility': 252,
#  'working': 253,
#  'develop': 254,
#  'her': 255,
#  'own': 256,
#  'language': 257,
#  'conspicuous': 258,
#  'success': 259,
#  'kosminsky': 260,
#  'puts': 261,
#  'enough': 262,
#  'salt': 263,
#  'into': 264,
#  'wounds': 265,
#  'tortured': 266,
#  'self': 267,
#  'conscious': 268,
#  'material': 269,
#  'make': 270,
#  'sting': 271,
#  'entertaining': 272,
#  'robert': 273,
#  'rodriguez': 274,
#  'decide': 275,
#  'need': 276,
#  'bolstered': 277,
#  'astonishing': 278,
#  'voice': 279,
#  'excepting': 280,
#  'love': 281,
#  'hewitt': 282,
#  'racial': 283,
#  'tension': 284,
#  'storyline': 285,
#  'have': 286,
#  'n': 287,
#  't': 288,
#  'encountered': 289,
#  'since': 290,
#  'least': 291,
#  'pete': 292,
#  'dragon': 293,
#  'fresh': 294,
#  'looks': 295,
#  'relationships': 296,
#  'minus': 297,
#  'traditional': 298,
#  'gender': 299,
#  'roles': 300,
#  'rambling': 301,
#  'ensemble': 302,
#  'piece': 303,
#  'loosely': 304,
#  'connected': 305,
#  'characters': 306,
#  'plots': 307,
#  'never': 308,
#  'quite': 309,
#  'gel': 310,
#  'charming': 311,
#  'overly': 312,
#  'complicated': 313,
#  'such': 314,
#  'movie': 315,
#  'claim': 316,
#  'express': 317,
#  'warmth': 318,
#  'longing': 319,
#  'even': 320,
#  'many': 321,
#  'these': 322,
#  'guys': 323,
#  'less': 324,
#  'adorable': 325,
#  'lamentations': 326,
#  'pretty': 327,
#  'much': 328,
#  'centered': 329,
#  'something': 330,
#  'vital': 331,
#  'about': 332,
#  'story': 333,
#  'elements': 334,
#  'romance': 335,
#  'tragedy': 336,
#  'silent': 337,
#  'children': 338,
#  'truest': 339,
#  'sense': 340,
#  'slap': 341,
#  'she': 342,
#  'not': 343,
#  'funny': 344,
#  'amateurish': 345,
#  'minor': 346,
#  'treat': 347,
#  'deuces': 348,
#  'wild': 349,
#  'encyclopedia': 350,
#  'shoplifts': 351,
#  'shamelessly': 352,
#  'farewell': 353,
#  'to': 354,
#  'innocence': 355,
#  'movies': 356,
#  'wanderers': 357,
#  'bronx': 358,
#  'tale': 359,
#  'without': 360,
#  'cribbing': 361,
#  'any': 362,
#  'intelligence': 363,
#  'truth': 364,
#  'stranger': 365,
#  'fiction': 366,
#  'chateau': 367,
#  'belongs': 368,
#  'rudd': 369,
#  'whose': 370,
#  'therapy': 371,
#  'dependent': 372,
#  'flakeball': 373,
#  'spouting': 374,
#  'french': 375,
#  'malapropisms': 376,
#  'nonstop': 377,
#  'maggie': 378,
#  'amazing': 379,
#  'breakthrough': 380,
#  'starring': 381,
#  'role': 382,
#  'eats': 383,
#  'screen': 384,
#  'animated': 385,
#  'sequences': 386,
#  'well': 387,
#  'done': 388,
#  'perfectly': 389,
#  'constructed': 390,
#  'convey': 391,
#  'childhood': 392,
#  'imagination': 393,
#  'creating': 394,
#  'adventure': 395,
#  'angst': 396,
#  'could': 397,
#  'young': 398,
#  'romantics': 399,
#  'date': 400,
#  'frida': 401,
#  'dealing': 402,
#  'dreams': 403,
#  'visions': 404,
#  'being': 405,
#  'told': 406,
#  'actually': 407,
#  'happened': 408,
#  'were': 409,
#  'third': 410,
#  'ending': 411,
#  'clue': 412,
#  'pure': 413,
#  'exciting': 414,
#  'moviemaking': 415,
#  'animation': 416,
#  'offer': 417,
#  'daytime': 418,
#  'serviceability': 419,
#  'big': 420,
#  'scooby': 421,
#  'silly': 422,
#  'original': 423,
#  'cartoon': 424,
#  'seem': 425,
#  'smart': 426,
#  'crafted': 427,
#  'comparison': 428,
#  'pretend': 429,
#  'your': 430,
#  'sat': 431,
#  'scores': 432,
#  'below': 433,
#  'might': 434,
#  'notice': 435,
#  'flaws': 436,
#  'important': 437,
#  'critically': 438,
#  'insightful': 439,
#  'godard': 440,
#  'still': 441,
#  'smarter': 442,
#  'work': 443,
#  'borstal': 444,
#  'boy': 445,
#  'especially': 446,
#  'realistic': 447,
#  'engaging': 448,
#  'nostalgia': 449,
#  'a': 450,
#  'list': 451,
#  'brit': 452,
#  'actors': 453,
#  'worth': 454,
#  'searching': 455,
#  'historical': 456,
#  'filmmaking': 457,
#  'balm': 458,
#  'right': 459,
#  'ideology': 460,
#  'either': 461,
#  'liberal': 462,
#  'conservative': 463,
#  'acting': 464,
#  'acted': 465,
#  'simply': 466,
#  'does': 467,
#  'they': 468,
#  'succeed': 469,
#  'merrily': 470,
#  'noble': 471,
#  'endeavor': 472,
#  'constant': 473,
#  'mood': 474,
#  'melancholy': 475,
#  'unhurried': 476,
#  'narrative': 477,
#  'masterfully': 478,
#  'controlled': 479,
#  'relentlessly': 480,
#  'saccharine': 481,
#  'clear': 482,
#  'case': 483,
#  'preaching': 484,
#  'converted': 485,
#  'seagal': 486,
#  'danny': 487,
#  'aiello': 488,
#  'days': 489,
#  'mumbles': 490,
#  'here': 491,
#  'seems': 492,
#  'analyze': 493,
#  'joe': 494,
#  'viterelli': 495,
#  'niro': 496,
#  'hand': 497,
#  'goombah': 498,
#  'unseemly': 499,
#  'same': 500,
#  'congratulate': 501,
#  'himself': 502,
#  'for': 503,
#  'having': 504,
#  'guts': 505,
#  'confront': 506,
#  'tender': 507,
#  'sermon': 508,
#  'year': 509,
#  'welsh': 510,
#  'curious': 511,
#  'god': 512,
#  'girls': 513,
#  'learns': 514,
#  'believing': 515,
#  'matter': 516,
#  'emerge': 517,
#  'dazed': 518,
#  'confused': 519,
#  'whether': 520,
#  've': 521,
#  'seen': 522,
#  'pornography': 523,
#  'documentary': 524,
#  'thanks': 525,
#  'small': 526,
#  'star': 527,
#  'heart': 528,
#  'family': 529,
#  'sequel': 530,
#  'plenty': 531,
#  'wife': 532,
#  'plotting': 533,
#  'special': 534,
#  'delivery': 535,
#  'matters': 536,
#  'scenic': 537,
#  'appeal': 538,
#  'cesspool': 539,
#  'steers': 540,
#  'feature': 541,
#  'debut': 542,
#  'created': 543,
#  'brilliant': 544,
#  'motion': 545,
#  'picture': 546,
#  'static': 547,
#  'sugary': 548,
#  'half': 549,
#  'hour': 550,
#  'after': 551,
#  'school': 552,
#  'interfaith': 553,
#  'understanding': 554,
#  'stretched': 555,
#  'minutes': 556,
#  'ingenious': 557,
#  'rich': 558,
#  'luscious': 559,
#  'cares': 560,
#  'too': 561,
#  'ignore': 562,
#  'smugly': 563,
#  'superior': 564,
#  'ends': 565,
#  'slapping': 566,
#  'target': 567,
#  'audience': 568,
#  'face': 569,
#  'shooting': 570,
#  'itself': 571,
#  'foot': 572,
#  'punch': 573,
#  'lines': 574,
#  'miss': 575,
#  'unfortunately': 576,
#  'outnumber': 577,
#  'hits': 578,
#  'three': 579,
#  'one': 580,
#  'turns': 581,
#  'collectively': 582,
#  'stellar': 583,
#  'performance': 584,
#  'writing': 585,
#  'tight': 586,
#  'truthful': 587,
#  'full': 588,
#  'situations': 589,
#  'honest': 590,
#  'observations': 591,
#  'partly': 592,
#  'schmaltzy': 593,
#  'by': 594,
#  'numbers': 595,
#  'shallow': 596,
#  'rumination': 597,
#  'emptiness': 598,
#  'entirely': 599,
#  'soulless': 600,
#  'buy': 601,
#  'mr': 602,
#  'broomfield': 603,
#  'findings': 604,
#  'acquires': 605,
#  'undeniable': 606,
#  'entertainment': 607,
#  'value': 608,
#  'slight': 609,
#  'pale': 610,
#  'continues': 611,
#  'force': 612,
#  'people': 613,
#  'would': 614,
#  'lesser': 615,
#  'men': 616,
#  'run': 617,
#  'cover': 618,
#  'let': 619,
#  'issue': 620,
#  'moratorium': 621,
#  'effective': 622,
#  'immediately': 623,
#  'treacly': 624,
#  'films': 625,
#  'inspirational': 626,
#  'prep': 627,
#  'professors': 628,
#  'heartwarmingly': 629,
#  'motivate': 630,
#  'gripping': 631,
#  'band': 632,
#  'performances': 633,
#  'featured': 634,
#  'drumline': 635,
#  'red': 636,
#  'hot': 637,
#  'mere': 638,
#  'point': 639,
#  'view': 640,
#  'ice': 641,
#  'narc': 642,
#  'remind': 643,
#  'crime': 644,
#  'dramas': 645,
#  'becoming': 646,
#  'sloughs': 647,
#  'mire': 648,
#  'alleged': 649,
#  'search': 650,
#  'purpose': 651,
#  'mckay': 652,
#  'embarrassed': 653,
#  'invention': 654,
#  'tries': 655,
#  'rush': 656,
#  'intermediary': 657,
#  'passages': 658,
#  'apparently': 659,
#  'hoping': 660,
#  'glaring': 661,
#  'triteness': 662,
#  'device': 663,
#  'put': 664,
#  'service': 665,
#  'hate': 666,
#  'goldmember': 667,
#  'justify': 668,
#  'embarrassment': 669,
#  'bringing': 670,
#  'barf': 671,
#  'bag': 672,
#  'moviehouse': 673,
#  'maudlin': 674,
#  'unfolds': 675,
#  'suggests': 676,
#  'fighting': 677,
#  'against': 678,
#  'urge': 679,
#  'sensationalize': 680,
#  'uncertain': 681,
#  'start': 682,
#  'murder': 683,
#  'generally': 684,
#  'sustains': 685,
#  'higher': 686,
#  'plateau': 687,
#  'bullock': 688,
#  'memorable': 689,
#  'interrogation': 690,
#  'gosling': 691,
#  'inescapable': 692,
#  'absurdities': 693,
#  'tantamount': 694,
#  'insulting': 695,
#  'living': 696,
#  'under': 697,
#  'sept': 698,
#  'overall': 699,
#  'vibe': 700,
#  'druggy': 701,
#  'indulgent': 702,
#  'spring': 703,
#  'break': 704,
#  'orgy': 705,
#  'pretentious': 706,
#  'arts': 707,
#  'majors': 708,
#  'pitfalls': 709,
#  'behavior': 710,
#  'circuit': 711,
#  'gets': 712,
#  'drawn': 713,
#  'party': 714,
#  'ambitious': 715,
#  'shiner': 716,
#  'organizing': 717,
#  'fight': 718,
#  'pulls': 719,
#  'off': 720,
#  'effects': 721,
#  'ones': 722,
#  'uplifting': 723,
#  'document': 724,
#  'worst': 725,
#  'possibilities': 726,
#  'mankind': 727,
#  'among': 728,
#  'best': 729,
#  'thinks': 730,
#  'marshall': 731,
#  'suspenseful': 732,
#  'spin': 733,
#  'standard': 734,
#  'horror': 735,
#  'flick': 736,
#  'formula': 737,
#  'delightful': 738,
#  'revels': 739,
#  'simplicity': 740,
#  'mostly': 741,
#  'martha': 742,
#  'leave': 743,
#  'grumble': 744,
#  'stomach': 745,
#  'sidedness': 746,
#  'flirts': 747,
#  'propaganda': 748,
#  'clearly': 749,
#  'intentioned': 750,
#  'cross': 751,
#  'cultural': 752,
#  'soap': 753,
#  'opera': 754,
#  'formulaic': 755,
#  'stilted': 756,
#  'difficult': 757,
#  'care': 758,
#  'character': 759,
#  'central': 760,
#  'flaw': 761,
#  'empire': 762,
#  'mind': 763,
#  'wants': 764,
#  'gangster': 765,
#  'art': 766,
#  'alice': 767,
#  'looking': 768,
#  'glass': 769,
#  'zombie': 770,
#  'land': 771,
#  'filled': 772,
#  'strange': 773,
#  'wonderful': 774,
#  'creatures': 775,
#  'sandler': 776,
#  'running': 777,
#  'repeating': 778,
#  'already': 779,
#  'often': 780,
#  'cool': 781,
#  'warm': 782,
#  'hearts': 783,
#  'enthusiasts': 784,
#  'ages': 785,
#  'feel': 786,
#  'anything': 787,
#  'result': 788,
#  'basically': 789,
#  'curiosity': 790,
#  'ultimately': 791,
#  'heady': 792,
#  'preachy': 793,
#  'serious': 794,
#  'goers': 795,
#  'embarking': 796,
#  'upon': 797,
#  'journey': 798,
#  'find': 799,
#  'perdition': 800,
#  'leads': 801,
#  'satisfying': 802,
#  'destination': 803,
#  'roman': 804,
#  'polanski': 805,
#  'directs': 806,
#  'pianist': 807,
#  'surgeon': 808,
#  'mends': 809,
#  'broken': 810,
#  'meticulously': 811,
#  'passion': 812,
#  'taken': 813,
#  'nosedive': 814,
#  'alfred': 815,
#  'hitchcock': 816,
#  'imaginative': 817,
#  'flight': 818,
#  'shyamalan': 819,
#  'summer': 820,
#  'fluff': 821,
#  'downright': 822,
#  'transparent': 823,
#  'script': 824,
#  'endless': 825,
#  'assault': 826,
#  'embarrassingly': 827,
#  'ham': 828,
#  'fisted': 829,
#  'sex': 830,
#  'jokes': 831,
#  'reek': 832,
#  'rewrite': 833,
#  'designed': 834,
#  'garner': 835,
#  'cooler': 836,
#  'pg': 837,
#  'rating': 838,
#  'denying': 839,
#  'burns': 840,
#  'filmmaker': 841,
#  'bright': 842,
#  'future': 843,
#  'him': 844,
#  'hell': 845,
#  'fat': 846,
#  'liar': 847,
#  'home': 848,
#  'alone': 849,
#  'raised': 850,
#  'deprecating': 851,
#  'level': 852,
#  'conjured': 853,
#  'coming': 854,
#  'of': 855,
#  'age': 856,
#  'stories': 857,
#  'cat': 858,
#  'infuriatingly': 859,
#  'quirky': 860,
#  'style': 861,
#  'making': 862,
#  'guilty': 863,
#  'descriptions': 864,
#  'suit': 865,
#  'evelyn': 866,
#  'besotted': 867,
#  'obvious': 868,
#  'tells': 869,
#  'awesome': 870,
#  'ineffable': 871,
#  'elusive': 872,
#  'inexplicably': 873,
#  'powerful': 874,
#  'scope': 875,
#  'formed': 876,
#  'steamy': 877,
#  'last': 878,
#  'week': 879,
#  'pork': 880,
#  'dumplings': 881,
#  'affinity': 882,
#  'clockstoppers': 883,
#  'those': 884,
#  'crazy': 885,
#  'mixed': 886,
#  'up': 887,
#  'know': 888,
#  'grows': 889,
#  'strikes': 890,
#  'hardest': 891,
#  'reminds': 892,
#  'pertinent': 893,
#  'dynamics': 894,
#  'remain': 895,
#  'average': 896,
#  'kid': 897,
#  'empowerment': 898,
#  'fantasy': 899,
#  'slightly': 900,
#  'above': 901,
#  'brains': 902,
#  'yes': 903,
#  'spirited': 904,
#  'away': 905,
#  'triumph': 906,
#  'also': 907,
#  'failure': 908,
#  'storytelling': 909,
#  'slick': 910,
#  'engrossing': 911,
#  'melodrama': 912,
#  'comic': 913,
#  'book': 914,
#  'maguire': 915,
#  'soul': 916,
#  'serry': 917,
#  'ability': 918,
#  'essentially': 919,
#  'contained': 920,
#  'conflict': 921,
#  'larger': 922,
#  'context': 923,
#  'want': 924,
#  'money': 925,
#  'precise': 926,
#  'nature': 927,
#  'matthew': 928,
#  'predicament': 929,
#  'finally': 930,
#  'comes': 931,
#  'sharp': 932,
#  'focus': 933,
#  'revelation': 934,
#  'fails': 935,
#  'build': 936,
#  'compelling': 937,
#  'gut': 938,
#  'clutching': 939,
#  'advocacy': 940,
#  'cinema': 941,
#  'carries': 942,
#  'along': 943,
#  'torrent': 944,
#  'emotion': 945,
#  'explores': 946,
#  'awful': 947,
#  'complications': 948,
#  'terrifying': 949,
#  'day': 950,
#  'lazy': 951,
#  'taking': 952,
#  'hands': 953,
#  'approach': 954,
#  'shaped': 955,
#  'show': 956,
#  'why': 957,
#  'grinds': 958,
#  'increasingly': 959,
#  'incoherent': 960,
#  'fashion': 961,
#  'wishing': 962,
#  'watch': 963,
#  'faster': 964,
#  'around': 965,
#  'angel': 966,
#  'presents': 967,
#  'events': 968,
#  'aurelie': 969,
#  'christelle': 970,
#  'infuses': 971,
#  'particularly': 972,
#  'nightmarish': 973,
#  'fairytale': 974,
#  'gangs': 975,
#  'gravity': 976,
#  'subject': 977,
#  'good': 978,
#  'spaghetti': 979,
#  'western': 980,
#  'final': 981,
#  'verdict': 982,
#  'before': 983,
#  'better': 984,
#  'knowing': 985,
#  'happen': 986,
#  'willing': 987,
#  'earnestness': 988,
#  'execution': 989,
#  'skill': 990,
#  'few': 991,
#  'twists': 992,
#  'divine': 993,
#  'monument': 994,
#  'single': 995,
#  'struggle': 996,
#  'regain': 997,
#  'dignity': 998,
#  'music': 999,
#  ...}

# %%
print("Vocab size = {}".format(len(word_to_ix)))
# Out:
# Vocab size = 17454

# %%
label_to_ix = { "NEG": 0, "POS": 1 }

# %% [markdown]
# ## 5. Making dataset iterable

# %%
batch_size = 50
n_iters = 3000
num_epochs = n_iters/(len(x_train) / batch_size)
num_epochs = int(num_epochs)

# %%
## iterable datasets
train_data=list(zip(x_train,y_train))
train_data
# Out:
# [('starts intense political and psychological thriller but sabotaged ticking time bombs and other hollywood action cliches',
#   'NEG'),
#  ('while kids will probably eat the whole thing most adults will way ahead the plot',
#   'NEG'),
#  ('hoot watching the rock chomp jumbo ants pull arrow out his back and leap unscathed through raging fire',
#   'POS'),
#  ('but how washed out despite all that the project prime mystery', 'NEG'),
#  ('laggard drama wending its way uninspired philosophical epiphany', 'NEG'),
#  ('feels like cold old man going through the motions', 'NEG'),
#  ('while the path may familiar first time director denzel washington and top notch cast manage keep things interesting',
#   'POS'),
#  ('empty shell epic rather than the real deal', 'NEG'),
#  ('reeboir varies between sweet smile and angry bark while said attempts wear down possible pupils through repetition',
#   'NEG'),
#  ('cloaks familiar anti feminist equation lrb career kids misery rrb tiresome romantic comedy duds',
#   'NEG'),
#  ('the dangerous lives altar boys take adolescence feels painfully true',
#   'POS'),
#  ('anyone who welcomes dash the avant garde fused with their humor should take pleasure this crazed joyous romp film',
#   'POS'),
#  ('usually bad sign when directors abandon their scripts and where the moment takes them but olympia wash based filmmakers anne marcken and marilyn freeman did just that and what makes their project interesting',
#   'POS'),
#  ('nothing can detract from the affection that moral favorite friends will friends through thick and thin',
#   'POS'),
#  ('just when you think that every possible angle has been exhausted documentarians another new film emerges with yet another remarkable yet shockingly little known perspective',
#   'POS'),
#  ('road trip that will get you thinking are there yet', 'NEG'),
#  ('beautiful paean time long past', 'POS'),
#  ('graceful moving tribute the courage new york finest and nicely understated expression the grief shared the nation their sacrifice',
#   'POS'),
#  ('tense terrific sweaty palmed fun', 'POS'),
#  ('hugely accomplished slice hitchcockian suspense', 'POS'),
#  ('hypnotic portrait this sad compulsive life', 'POS'),
#  ('the trashy teen sleaze equivalent showgirls', 'NEG'),
#  ('more enjoyable than expected though and that because the laughs come from fairly basic comedic constructs',
#   'POS'),
#  ('this film different from the apple and striking that can only encourage see samira makhmalbaf very distinctive sensibility working develop her own film language with conspicuous success',
#   'POS'),
#  ('kosminsky puts enough salt into the wounds the tortured and self conscious material make sting',
#   'POS'),
#  ('another entertaining romp from robert rodriguez', 'POS'),
#  ('you decide you need see', 'NEG'),
#  ('bolstered astonishing voice cast lrb excepting love hewitt rrb interesting racial tension and storyline that have n t encountered since least pete dragon',
#   'POS'),
#  ('fresh entertaining comedy that looks relationships minus traditional gender roles',
#   'POS'),
#  ('rambling ensemble piece with loosely connected characters and plots that never quite gel',
#   'NEG'),
#  ('charming overly complicated ', 'NEG'),
#  ('how can such cold movie claim express warmth and longing', 'NEG'),
#  ('even though many these guys are less than adorable lrb their lamentations are pretty much self centered rrb there something vital about the movie',
#   'POS'),
#  ('the story that emerges has elements romance tragedy and even silent movie comedy',
#   'POS'),
#  ('this children film the truest sense', 'POS'),
#  ('slap her she not funny', 'NEG'),
#  ('the movie amateurish but minor treat', 'POS'),
#  ('deuces wild encyclopedia cliches that shoplifts shamelessly from farewell to innocence movies like the wanderers and bronx tale without cribbing any their intelligence',
#   'NEG'),
#  ('truth stranger than fiction', 'NEG'),
#  ('the chateau belongs rudd whose portrait therapy dependent flakeball spouting french malapropisms nonstop hoot',
#   'POS'),
#  ('maggie makes amazing breakthrough her first starring role and eats the screen',
#   'POS'),
#  ('the animated sequences are well done and perfectly constructed convey sense childhood imagination and creating adventure out angst',
#   'POS'),
#  ('could young romantics out date', 'POS'),
#  ('frida n t that much different from many hollywood romance', 'NEG'),
#  ('are dealing with dreams visions being told what actually happened were the third ending clue',
#   'NEG'),
#  ('this pure exciting moviemaking', 'POS'),
#  ('its plot and animation offer daytime serviceability but little more',
#   'NEG'),
#  ('the big screen scooby makes the silly original cartoon seem smart and well crafted comparison',
#   'NEG'),
#  ('pretend like your sat scores are below and you might not notice the flaws',
#   'NEG'),
#  ('moving and important film', 'POS'),
#  ('even when not his most critically insightful godard can still smarter than any other filmmakers still work',
#   'POS'),
#  ('borstal boy n t especially realistic engaging nostalgia piece', 'NEG'),
#  ('with cast a list brit actors worth searching out', 'POS'),
#  ('this historical filmmaking without the balm right thinking ideology either liberal conservative',
#   'POS'),
#  ('acting can not acted', 'NEG'),
#  ('well acted movie that simply does n t gel', 'NEG'),
#  ('and they succeed merrily their noble endeavor', 'POS'),
#  ('the film constant mood melancholy and its unhurried narrative are masterfully controlled',
#   'POS'),
#  ('this long and relentlessly saccharine film clear case preaching the converted',
#   'NEG'),
#  ('seagal who looks more like danny aiello these days mumbles his way through the movie',
#   'NEG'),
#  ('nothing here seems funny did analyze this not even joe viterelli niro right hand goombah',
#   'NEG'),
#  ('the director seems take unseemly pleasure lrb the characters rrb misery and the same time congratulate himself for having the guts confront',
#   'NEG'),
#  ('sweet tender sermon about year old welsh boy more curious about god than girls who learns that believing something does matter',
#   'POS'),
#  ('you emerge dazed confused whether you ve seen pornography documentary',
#   'NEG'),
#  ('thanks small star with big heart this family film sequel plenty fun for all',
#   'POS'),
#  ('wife plotting nothing special the delivery that matters here', 'NEG'),
#  ('has all the scenic appeal cesspool', 'NEG'),
#  ('steers his feature film debut has created brilliant motion picture', 'POS'),
#  ('static and sugary little half hour after school special about interfaith understanding stretched out minutes',
#   'NEG'),
#  ('the movie ingenious fun', 'POS'),
#  ('when this rich and luscious who cares', 'POS'),
#  ('too smart ignore but little too smugly superior like this could movie that ends slapping its target audience the face shooting itself the foot',
#   'NEG'),
#  ('the punch lines that miss unfortunately outnumber the hits three to one',
#   'NEG'),
#  ('the ensemble cast turns collectively stellar performance and the writing tight and truthful full funny situations and honest observations',
#   'POS'),
#  ('partly schmaltzy by the numbers romantic comedy partly shallow rumination the emptiness success and entirely soulless',
#   'NEG'),
#  ('whether not you buy mr broomfield findings the film acquires undeniable entertainment value the slight pale mr broomfield continues force himself people and into situations that would make lesser men run for cover',
#   'POS'),
#  ('let issue moratorium effective immediately treacly films about inspirational prep school professors and the children they heartwarmingly motivate',
#   'POS'),
#  ('gripping drama', 'POS'),
#  ('the band performances featured drumline are red hot lrb but rrb from mere story point view the film ice cold',
#   'NEG'),
#  ('narc can only remind brilliant crime dramas without becoming one itself',
#   'NEG'),
#  ('one sloughs one way through the mire this alleged psychological thriller search purpose even plot',
#   'NEG'),
#  ('mckay seems embarrassed his own invention and tries rush through the intermediary passages apparently hoping that the audience will not notice the glaring triteness the plot device has put service',
#   'NEG'),
#  ('hate', 'NEG'),
#  ('goldmember funny enough justify the embarrassment bringing barf bag the moviehouse',
#   'NEG'),
#  (' the maudlin way its story unfolds suggests director fighting against the urge sensationalize his material',
#   'NEG'),
#  ('after uncertain start murder hits and generally sustains higher plateau with bullock memorable first interrogation gosling',
#   'POS'),
#  ('its inescapable absurdities are tantamount insulting the intelligence anyone who has n t been living under rock lrb since sept rrb ',
#   'NEG'),
#  ('the overall vibe druggy and self indulgent like spring break orgy for pretentious arts majors',
#   'NEG'),
#  ('like most movies about the pitfalls bad behavior circuit gets drawn into the party',
#   'NEG'),
#  ('ambitious movie that like shiner organizing the big fight pulls off enough its effects make for the ones that n t come off',
#   'POS'),
#  ('uplifting only document the worst possibilities mankind can and among the best films the year',
#   'POS'),
#  ('less funny than should and less funny than thinks', 'NEG'),
#  ('marshall puts suspenseful spin standard horror flick formula', 'POS'),
#  ('delightful little film that revels its own simplicity mostly martha will leave you with smile your face and grumble your stomach',
#   'POS'),
#  ('its one sidedness flirts with propaganda', 'NEG'),
#  ('though clearly well intentioned this cross cultural soap opera painfully formulaic and stilted',
#   'NEG'),
#  ('very difficult care about the character and that the central flaw the film',
#   'NEG'),
#  ('empire n t make its mind whether wants gangster flick art film', 'NEG'),
#  ('alice adventure through the looking glass and into zombie land filled with strange and wonderful creatures',
#   'POS'),
#  ('this sandler running empty repeating what already done way too often',
#   'NEG'),
#  (' there enough cool fun here warm the hearts animation enthusiasts all ages',
#   'POS'),
#  ('never feel anything for these characters and result the film basically just curiosity',
#   'NEG'),
#  ('ultimately the movie too heady for children and too preachy for adults',
#   'NEG'),
#  ('serious movie goers embarking upon this journey will find that the road perdition leads satisfying destination',
#   'POS'),
#  ('one the best movies the year', 'POS'),
#  ('roman polanski directs the pianist like surgeon mends broken heart very meticulously but without any passion',
#   'NEG'),
#  ('hollywood has taken quite nosedive from alfred hitchcock imaginative flight shyamalan self important summer fluff',
#   'NEG'),
#  ('downright transparent the script endless assault embarrassingly ham fisted sex jokes that reek script rewrite designed garner the film cooler pg rating',
#   'NEG'),
#  ('there denying that burns filmmaker with bright future ahead him', 'POS'),
#  ('what the hell', 'NEG'),
#  ('big fat liar little more than home alone raised new self deprecating level',
#   'NEG'),
#  ('the year has conjured more coming of age stories than seem possible but take care cat emerges the very best them',
#   'POS'),
#  ('too infuriatingly quirky and taken with its own style', 'NEG'),
#  ('will warm your heart without making you feel guilty about', 'POS'),
#  ('all three descriptions suit evelyn besotted and obvious drama that tells nothing new',
#   'NEG'),
#  ('awesome work ineffable elusive yet inexplicably powerful', 'POS'),
#  ('the film small scope yet perfectly formed', 'POS'),
#  ('steamy last week pork dumplings', 'NEG'),
#  ('you have affinity for most the characters', 'NEG'),
#  ('clockstoppers one those crazy mixed up films that does n t know what wants when grows',
#   'NEG'),
#  ('strikes hardest when reminds you how pertinent its dynamics remain', 'POS'),
#  ('average kid empowerment fantasy with slightly above average brains', 'POS'),
#  ('yes spirited away triumph imagination but also failure storytelling',
#   'NEG'),
#  ('slick engrossing melodrama', 'POS'),
#  ('still comic book but maguire makes comic book with soul', 'POS'),
#  ('what makes this film special serry ability take what essentially contained family conflict and put into much larger historical context',
#   'POS'),
#  ('still want money back', 'NEG'),
#  ('when the precise nature matthew predicament finally comes into sharp focus the revelation fails justify the build up',
#   'NEG'),
#  ('compelling gut clutching piece advocacy cinema that carries you along torrent emotion explores the awful complications one terrifying day',
#   'POS'),
#  ('lazy filmmaking with the director taking hands off approach when should have shaped the story show why compelling',
#   'NEG'),
#  ('the time the plot grinds itself out increasingly incoherent fashion you might wishing for watch that makes time faster rather than the other way around',
#   'NEG'),
#  ('angel presents events partly from the perspective aurelie and christelle and infuses the film with the sensibility particularly nightmarish fairytale',
#   'POS'),
#  ('gangs despite the gravity its subject matter often fun watch good spaghetti western',
#   'NEG'),
#  ('final verdict you ve seen all before', 'NEG'),
#  ('better knowing full well what going happen but willing let the earnestness its execution and skill its cast take you down familiar road with few twists',
#   'POS'),
#  ('here divine monument single man struggle regain his life his dignity and his music',
#   'POS'),
#  ('that haynes can both maintain and dismantle the facades that his genre and his character construct wonderous accomplishment veracity and narrative grace',
#   'POS'),
#  ('the densest distillation roberts movies ever made', 'NEG'),
#  ('ragbag cliches', 'NEG'),
#  ('sentimental but feels free offend analytical and then surrenders the illogic its characters about grief and yet permits laughter',
#   'POS'),
#  ('was filled with shootings beatings and more cussing than you could shake stick',
#   'NEG'),
#  ('neither rousing success nor blinding embarrassment', 'NEG'),
#  ('schrader aims present unflinching look one man downfall brought about his lack self awareness',
#   'NEG'),
#  ('that rare family movie genuine and sweet without relying animation dumb humor',
#   'POS'),
#  ('been done before but never vividly with much passion', 'POS'),
#  (' had been only half an hour long special the humor would have been fast and furious ninety minutes drags',
#   'NEG'),
#  ('the plot has number holes and times simply baffling', 'NEG'),
#  ('film delicate interpersonal dances', 'POS'),
#  ('all too familiar basically the sort cautionary tale that was old when angels with dirty faces appeared ',
#   'NEG'),
#  ('strength documentary disregard available bias especially temptingly easy would have been with this premise',
#   'POS'),
#  ('director peter kosminsky gives these women forum demonstrate their acting chops and they take full advantage',
#   'POS'),
#  ('ram dass fierce grace moulds itself example up and coming documentarians the overlooked pitfalls such endeavour',
#   'NEG'),
#  ('robin williams has thankfully ditched the saccharine sentimentality bicentennial man favour altogether darker side',
#   'POS'),
#  ('the movie were all comedy might work better', 'NEG'),
#  ('the otherwise good naturedness mr deeds with its embrace sheer goofiness and cameos less than likely new york celebrities certainly raises the film above anything sandler been attached before',
#   'POS'),
#  ('science fiction movie minority report astounds', 'POS'),
#  ('the movie while beautiful feels labored with hint the writing exercise about',
#   'NEG'),
#  ('often likable but just often meandering low energy and too eager quirky moments when little old fashioned storytelling would come handy',
#   'POS'),
#  ('the histrionic muse still eludes madonna and playing charmless witch she merely charmless witch',
#   'NEG'),
#  ('while longer possess the lack of attention span that did seventeen had trouble sitting for blade',
#   'POS'),
#  ('lavishly exhilaratingly tasteless', 'NEG'),
#  ('not going everyone bag popcorn but definitely gives you something chew',
#   'POS'),
#  ('listless and desultory affair', 'NEG'),
#  ('whereas the extremely competent hitman films such pulp fiction and get shorty resonate sardonic verve their caustic purpose for existing who cletis tout',
#   'NEG'),
#  ('the only camouflage carvey should now considering paper bag wear over his head when goes out into public avoid being recognized the man who bilked unsuspecting moviegoers',
#   'NEG'),
#  ('period costume and with bigger budget', 'NEG'),
#  (' lrb rrb has the feel summer popcorn movie', 'NEG'),
#  ('smart sassy and exceptionally charming romantic comedy', 'POS'),
#  ('what surprising how well holds era which computer generated images are the norm',
#   'POS'),
#  ('hilarious musical comedy though stymied accents thick mud', 'NEG'),
#  ('proves mainly that south korean filmmakers can make undemanding action movies with all the alacrity their hollywood counterparts',
#   'NEG'),
#  ('predecessors the mummy and the mummy returns stand intellectual masterpieces next the scorpion king',
#   'NEG'),
#  ('when comes out video then the perfect cure for insomnia', 'NEG'),
#  ('only had the story match', 'NEG'),
#  ('squanders chan uniqueness could even said squander jennifer love hewitt',
#   'NEG'),
#  ('the time you reach the finale you re likely wondering why you ve been watching all this strutting and posturing',
#   'NEG'),
#  ('the determination pinochet victims seek justice and their often heartbreaking testimony spoken directly into director patricio guzman camera pack powerful emotional wallop',
#   'POS'),
#  ('marinated', 'NEG'),
#  ('the acting pauline and paulette good all round but what really sets the film apart debrauwer refusal push the easy emotional buttons',
#   'POS'),
#  ('transcends its agenda deliver awe inspiring times sublime visuals and offer fascinating glimpse into the subculture extreme athletes whose derring do puts the into the games',
#   'POS'),
#  ('film that should relegated dark video store corner somehow making its way instead theaters',
#   'NEG'),
#  ('provides satisfactory overview the bizarre world extreme athletes several daredevils express their own views',
#   'POS'),
#  ('fred schepisi tale four englishmen facing the prospect their own mortality views youthful affluence not lost ideal but starting point',
#   'POS'),
#  ('more mature than fatal attraction more complete than indecent proposal and more relevant than weeks unfaithful once intimate and universal cinema',
#   'POS'),
#  ('film that begins with the everyday lives naval personnel san diego and ends with scenes true and heartbreaking that tears welled eyes both times saw the film',
#   'POS'),
#  ('insomnia loses points when surrenders formulaic bang bang shoot em up scene the conclusion',
#   'NEG'),
#  ('exactly what you expect from guy named kaos', 'NEG'),
#  (' the same tired old gags modernized for the extreme sports generation',
#   'NEG'),
#  ('summer clones harvard man something rare and riveting wild ride that relies more than special effects',
#   'POS'),
#  ('there are some laughs this movie but williams anarchy gets tiresome the satire weak',
#   'NEG'),
#  (' lrb rrb boldly stroked luridly coloured uni dimensional nonsense machine that strokes the eyeballs while evaporates like much crypt mist the brain',
#   'NEG'),
#  ('best this film for the under crowd', 'NEG'),
#  ('moving and solidly entertaining comedy drama that should bolster director and co writer',
#   'POS'),
#  ('quiet patient and tenacious mr lopez himself who approaches his difficult endless work with remarkable serenity and discipline',
#   'POS'),
#  ('too often son the bride becomes exercise trying predict when preordained big moment will occur and not',
#   'NEG'),
#  ('setup easy borders facile but keeping the film from cheap shot mediocrity its crack cast',
#   'POS'),
#  ('devoid pleasure sensuality that can not even dubbed hedonistic', 'NEG'),
#  ('for all its shoot outs fistfights and car chases this movie phlegmatic bore tedious makes the silly spy vs spy film the sum all fears starring ben affleck seem downright hitchcockian',
#   'NEG'),
#  ('elvira fans could hardly ask for more', 'POS'),
#  ('how you make movie with depth about man who lacked any', 'NEG'),
#  ('there truth here', 'POS'),
#  ('morton deserves oscar nomination', 'POS'),
#  ('frailty starts out like typical bible killer story but turns out significantly different lrb and better rrb than most films with this theme',
#   'POS'),
#  ('you need n t steeped s sociology pop culture movie lore appreciate the emotional depth haynes work',
#   'POS'),
#  ('confident richly acted emotionally devastating piece work and first great film',
#   'POS'),
#  ('unlike trey parker sandler does n t understand that the idea exploiting molestation for laughs funny not actually exploiting yourself',
#   'NEG'),
#  ('definitely improvement the first blade since does n t take itself deadly seriously',
#   'POS'),
#  ('maybe formula filmmaking but there nothing wrong with that the film well crafted and this one',
#   'POS'),
#  ('majidi direction has never been smoother more confident', 'POS'),
#  ('shanghai ghetto should applauded for finding new angle tireless story but you might want think twice before booking passage',
#   'NEG'),
#  ('the one hour mark herzog simply runs out ideas and the pace turns positively leaden the movie sputters its inevitable tragic conclusion',
#   'NEG'),
#  ('despite slick production values and director roger michell tick tock pacing the final effect like having two guys yelling your face for two hours',
#   'NEG'),
#  ('the film would have been more enjoyable had the balance shifted favor water bound action over the land based drama but the emphasis the latter leaves blue crush waterlogged',
#   'NEG'),
#  ('spite featuring script credited fewer than five writers apparently nobody here bothered check twice',
#   'NEG'),
#  ('you can watch giggle and get adrenaline boost without feeling like you ve completely lowered your entertainment standards',
#   'POS'),
#  ('never quite able overcome the cultural moat surrounding its ludicrous and contrived plot',
#   'NEG'),
#  ('solid piece journalistic work that draws picture man for whom political expedience became deadly foreign policy',
#   'NEG'),
#  ('the obnoxious title character provides the drama that gives added clout this doc',
#   'POS'),
#  ('poignant japanese epic about adolescent anomie and heartbreak', 'POS'),
#  ('you have once again entered the bizarre realm where director adrian lyne holds sway where all relationships are simultaneously broadly metaphorical oddly abstract and excruciatingly literal',
#   'NEG'),
#  ('gere gives good performance film that does n t merit', 'NEG'),
#  ('looks closely insightfully fragile complex relationships', 'POS'),
#  ('giggling the absurdities and inconsistencies part the fun', 'POS'),
#  ('the film appeal has lot with the casting juliette binoche sand who brings the role her pale dark beauty and characteristic warmth',
#   'POS'),
#  ('rather than real figures', 'NEG'),
#  ('girl meets girl romantic comedy kissing jessica steinis quirky charming and often hilarious',
#   'POS'),
#  ('you have n t seen the film lately you may surprised the variety tones spielberg work',
#   'POS'),
#  ('while certain cues like the happy music suggest that this movie supposed warm our hearts jeong hyang lee film just likely blacken that organ with cold vengefulness',
#   'NEG'),
#  ('may about drug dealers kidnapping and unsavory folks but the tone and pacing are shockingly intimate',
#   'NEG'),
#  ('please someone stop eric schaeffer before makes another film', 'NEG'),
#  ('while you have admit semi amusing watch robert deniro belt out when you re jet you re jet all the way equally distasteful watch him sing the lyrics tonight',
#   'NEG'),
#  ('this dreadfully earnest inversion the concubine love triangle eschews the previous film historical panorama and roiling pathos for bug eyed mugging and gay niche condescension',
#   'NEG'),
#  ('the pool drowned boredom', 'NEG'),
#  ('you may leave the theater with more questions than answers but darned your toes n t still tapping',
#   'POS'),
#  ('summary the plot does n t quite justice the awfulness the movie for that comes through all too painfully the execution',
#   'NEG'),
#  ('satisfyingly odd and intriguing tale was century and half ago has delightfully dour deadpan tone and stylistic consistency',
#   'POS'),
#  ('what most refreshing about real women have curves its unforced comedy drama and its relaxed natural seeming actors',
#   'POS'),
#  ('while puerile men dominate the story the women shine', 'NEG'),
#  ('light the chills and heavy the atmospheric weirdness and there are moments jaw droppingly odd behavior yet found weirdly appealing',
#   'POS'),
#  ('really need the tiger beat version', 'NEG'),
#  ('work that lacks both purpose and strong pulse', 'NEG'),
#  ('everything its title implies standard issue crime drama spat out from the tinseltown assembly line',
#   'NEG'),
#  ('the movie undone filmmaking methodology that just experimental enough alienate the mainstream audience while ringing cliched hardened indie heads',
#   'NEG'),
#  ('although purportedly study modern alienation really little more than particularly slanted gay s m fantasy enervating and deadeningly drawn out',
#   'NEG'),
#  ('the movie has respect for laws political correctness common decency but displays something more important respect for its flawed crazy people',
#   'NEG'),
#  ('she lioness protecting her cub and reluctant villain incapable controlling his crew',
#   'POS'),
#  ('depressingly retrograde post feminist romantic comedy that takes astonishingly condescending attitude toward women',
#   'NEG'),
#  ('frightful vanity film that doubt pays off what debt miramax felt they owed benigni',
#   'NEG'),
#  ('the film exudes the urbane sweetness that woody allen seems have bitterly forsaken',
#   'POS'),
#  ('like the best minutes', 'POS'),
#  ('the sight the spaceship the launching pad duly impressive imax dimensions are shots the astronauts floating their cabins',
#   'POS'),
#  ('the name allegedly inspiring and easily marketable flick the emperor club turns blind eye the very history pretends teach',
#   'NEG'),
#  ('equally spoofs and celebrates the more outre aspects black culture and the dorkier aspects white culture even points out how inseparable the two are',
#   'POS'),
#  ('you are willing this then you crazy', 'NEG'),
#  ('period story about catholic boy who tries help jewish friend get into heaven sending the audience straight hell',
#   'NEG'),
#  ('ong chooses present life slight weightless fairy tale whose most unpleasant details seem melt away the face the character blank faced optimism',
#   'NEG'),
#  ('spectacular every sense the word even you don know orc from uruk hai',
#   'POS'),
#  ('what elevates the movie above the run of the mill singles blender its surreal sense humor and technological finish',
#   'POS'),
#  ('each scene drags underscoring the obvious and sentiment slathered top',
#   'NEG'),
#  ('brilliantly written and well acted yellow asphalt uncompromising film',
#   'POS'),
#  ('everything else about high crimes like the military system justice portrays tiresomely regimented',
#   'NEG'),
#  ('their computer animated faces are very expressive', 'POS'),
#  ('the script tired one with few moments joy rising above the stale material',
#   'NEG'),
#  (' lrb raimi rrb matured quite bit with spider man even though one the most plain white toast comic book films you ll ever see',
#   'NEG'),
#  ('those prone indignation need not apply those susceptible blue hilarity step right',
#   'POS'),
#  ('often unfunny romp', 'NEG'),
#  ('brings together some the biggest names japanese anime with impressive results',
#   'POS'),
#  ('really advantage invest such subtlety and warmth animatronic bear when the humans are acting like puppets',
#   'NEG'),
#  ('your appreciation will depend what experiences you bring and what associations you choose make',
#   'NEG'),
#  ('ignore the reputation and ignore the film', 'NEG'),
#  ('complete waste time', 'NEG'),
#  ('such fine idea for film and such stultifying lifeless execution', 'NEG'),
#  ('jacquot has filmed the opera exactly the libretto directs ideally capturing the opera drama and lyricism',
#   'POS'),
#  ('when seagal appeared orange prison jumpsuit wanted stand the theater and shout hey kool aid',
#   'NEG'),
#  ('trying make head tail the story the hip hop indie snipes enough give you brain strain and the pay off negligible',
#   'NEG'),
#  ('lightweight but appealing', 'POS'),
#  ('michael moore has perfected the art highly entertaining self aggrandizing politically motivated documentary making and got potent topic ever here',
#   'POS'),
#  ('gripping documentary that reveals how deep the antagonism lies war torn jerusalem',
#   'POS'),
#  ('mawkish self parody that plays like some weird masterpiece theater sketch with neither point view nor compelling reason for being',
#   'NEG'),
#  ('exciting and well paced', 'POS'),
#  ('soderbergh like kubrick before him may not touch the planet skin but understands the workings its spirit',
#   'POS'),
#  ('even through its flaws revolution proves compelling interestingly told film',
#   'POS'),
#  ('conventional but well crafted film about historic legal battle ireland over man right raise his own children',
#   'POS'),
#  ('please', 'NEG'),
#  ('certain distasteful children and adults alike eight crazy nights total misfire',
#   'NEG'),
#  ('shame the marvelous first minutes have combined with the misconceived final',
#   'NEG'),
#  ('the movie certainly has its share clever moments and biting dialogue but there just not much lurking below its abstract surface',
#   'NEG'),
#  ('amid the shock and curiosity factors the film just corny examination young actress trying find her way',
#   'NEG'),
#  ('even accepting this the right frame mind can only provide with much leniency',
#   'NEG'),
#  ('the only question determine how well the schmaltz manufactured assess the quality the manipulative engineering',
#   'NEG'),
#  ('the plot plummets into comedy graveyard before janice comes racing the rescue the final reel',
#   'NEG'),
#  ('great companion piece other napoleon films', 'POS'),
#  ('has not much been written assembled frankenstein like out other marginally better shoot em ups',
#   'NEG'),
#  ('the most repugnant adaptation', 'NEG'),
#  ('though the film well intentioned one could rent the original and get the same love story and parable',
#   'POS'),
#  ('opening the play more has partly closed down', 'NEG'),
#  ('mckay shows crushingly little curiosity about ill equipped examine the interior lives the characters his film much less incorporate them into his narrative',
#   'NEG'),
#  ('the movie should jolt you out your seat couple times give you few laughs and leave you feeling like was worth your seven bucks even though does turn out bit cheat the end',
#   'POS'),
#  ('feel good movie that does n t give you enough feel good about', 'NEG'),
#  ('shallow', 'NEG'),
#  ('evokes the style and flash the double cross that made mamet house games and last fall heist much fun',
#   'POS'),
#  ('tadpole may one the most appealing movies ever made about otherwise appalling and downright creepy subject teenage boy love with his stepmother',
#   'POS'),
#  ('hugh grant who has good line charm has never been more charming than about boy',
#   'POS'),
#  ('the wanton slipperiness corpus and its amiable jerking and reshaping physical time and space would make great piece watch with kids and use introduce video art',
#   'POS'),
#  ('supposedly based upon real least soberly reported incidents the film ends with large human tragedy',
#   'NEG'),
#  ('unsuccessful attempt movie ideas', 'NEG'),
#  ('that the battery your watch has died', 'NEG'),
#  (' unlikable uninteresting unfunny and completely utterly inept', 'NEG'),
#  ('just too bad the screenwriters eventually shoot themselves the feet with cop flick cliches like oily arms dealer squad car pile ups and the requisite screaming captain',
#   'NEG'),
#  ('film could possibly more contemptuous the single female population', 'NEG'),
#  (' true delight', 'POS'),
#  ('conversations about one thing intelligent flick that examines many different ideas from happiness guilt intriguing bit storytelling',
#   'POS'),
#  ('literary desecrations this makes for perfectly acceptable occasionally very enjoyable children entertainment',
#   'POS'),
#  ('the kind movie that aside from robert altman spike lee the coen brothers and few others our moviemakers n t make often enough',
#   'POS'),
#  ('with obvious rapport with her actors and striking style behind the camera',
#   'POS'),
#  ('what makes salton sea surprisingly engrossing that caruso takes atypically hypnotic approach world that often handled fast edit hopped up fashion',
#   'POS'),
#  ('represents something very close the nadir the thriller horror genre',
#   'NEG'),
#  ('era where big stars and high production values are standard procedure narc strikes defiantly retro chord and outpaces its contemporaries with daring and verve',
#   'POS'),
#  ('true hollywood story', 'NEG'),
#  ('this movie that what pleasant distraction friday night diversion excuse eat popcorn',
#   'POS'),
#  ('the waterlogged script plumbs uncharted depths stupidity incoherence and sub sophomoric sexual banter',
#   'NEG'),
#  ('this hastily mounted production exists only capitalize hopkins inclination play hannibal lecter again even though harris has immediate inclination provide fourth book',
#   'NEG'),
#  ('features fincher characteristically startling visual style and almost palpable sense intensity',
#   'POS'),
#  ('writer director david jacobson and his star jeremy renner have made remarkable film that explores the monster psychology not order excuse him but rather demonstrate that his pathology evolved from human impulses that grew hideously twisted',
#   'POS'),
#  ('the importance being earnest movie seems missing great deal the acerbic repartee the play',
#   'NEG'),
#  ('really pan american movie with moments genuine insight into the urban heart',
#   'POS'),
#  ('one the best rock documentaries ever', 'POS'),
#  ('just another combination bad animation and mindless violence lacking the slightest bit wit charm',
#   'NEG'),
#  ('still like moonlight mile better judgment damned', 'POS'),
#  ('bluto blutarsky miss you', 'POS'),
#  ('what john does heroic but n t condone one the film stars recently said tortuous comment that perfectly illustrates the picture moral schizophrenia',
#   'NEG'),
#  ('city the sea gritty police thriller with all the dysfunctional family dynamics one could wish for',
#   'POS'),
#  (' funny yet dark and seedy clash cultures and generations', 'POS'),
#  ('what lacks originality makes for effective cheap moments fright and dread',
#   'NEG'),
#  (' lrb rrb wonderfully loopy tale love longing and voting', 'POS'),
#  ('one the most plain unimaginative romantic comedies ve ever seen', 'NEG'),
#  ('the characters are interesting and the relationship between yosuke and saeko worth watching develops but there not enough the story fill two hours',
#   'NEG'),
#  ('the screenplay never lets forget that bourne was once amoral assassin just like the ones who are pursuing him there never really true versus them',
#   'POS'),
#  ('too bad that the rest n t more compelling', 'NEG'),
#  ('writer director night shyamalan ability pull together easily accessible stories that resonate with profundity undeniable',
#   'POS'),
#  ('old fashioned but emotionally stirring adventure tale the kind they rarely make anymore',
#   'POS'),
#  ('merely lrb and literally rrb tosses around sex toys and offers half hearted paeans empowerment that are repeatedly undercut the brutality the jokes most women expense',
#   'NEG'),
#  ('got all the familiar bruckheimer elements and schumacher does probably good job anyone bringing off the hopkins rock collision acting styles and onscreen personas',
#   'POS'),
#  ('watches them they float within the seas their personalities', 'POS'),
#  ('fessenden narrative just much about the ownership and redefinition myth about domestic unit finding their way joy',
#   'POS'),
#  ('fascinating bombshell documentary that should shame americans regardless whether not ultimate blame finally lies with kissinger',
#   'POS'),
#  ('the gags and the script are mixed bag', 'NEG'),
#  ('movie about passion', 'NEG'),
#  ('gives lot chew but not all has been properly digested', 'NEG'),
#  ('there are times when you wish that the movie had worked little harder conceal its contrivances but brown sugar turns out sweet and enjoyable fantasy',
#   'NEG'),
#  ('there much look metropolis you hate tear your eyes away from the images long enough read the subtitles',
#   'POS'),
#  ('carrying off spot on scottish burr duvall lrb also producer rrb peels layers from this character that may well not have existed paper',
#   'POS'),
#  ('even the ring has familiar ring still unusually crafty and intelligent for hollywood horror',
#   'POS'),
#  ('the real star this movie the score the songs translate well film and really well directed',
#   'POS'),
#  ('movie that accomplishes much that one viewing n t possibly enough', 'POS'),
#  ('who needs mind bending drugs when they can see this the final part the qatsi trilogy directed godfrey reggio with music philip glass',
#   'POS'),
#  ('there sheer unbridled delight the way the story unfurls ', 'POS'),
#  (' trashy little bit fluff stuffed with enjoyable performances and bewildering sense self importance',
#   'NEG'),
#  ('some good organic character work lots obvious political insights and',
#   'POS'),
#  ('the screenplay comes across rather unintentionally hip hop scooby doo',
#   'NEG'),
#  ('the first question ask about bad company why anthony hopkins', 'NEG'),
#  ('sweet home alabama n t going win any academy awards but this date night diversion will definitely win some hearts',
#   'POS'),
#  ('the movie our story much schmidt matter viewed self reflection cautionary tale',
#   'NEG'),
#  ('now former gong show addict ll admit only complaint that did n t get more re creations all those famous moments from the show',
#   'POS'),
#  ('ice age n t drop your jaw but will warm your heart and giving strong thumbs',
#   'POS'),
#  ('teens only', 'NEG'),
#  ('this insultingly inept and artificial examination grief and its impacts upon the relationships the survivors',
#   'NEG'),
#  ('the predictability bland comfort food appeals you then the film pleasant enough dish',
#   'NEG'),
#  ('cutesy romantic tale with twist', 'POS'),
#  (' spiced with humor lrb speak fluent flatula advises denlopp after rather bubbly exchange with alien deckhand rrb and witty updatings lrb silver parrot has been replaced with morph cute alien creature who mimics everyone and everything around rrb ',
#   'POS'),
#  ('n t even care that there plot this antonio banderas lucy liu faceoff',
#   'NEG'),
#  ('there nothing remotely topical sexy here', 'NEG'),
#  (' contains very few laughs and even less surprises', 'NEG'),
#  ('tough being black man america especially when the man has taken away your car your work hours and denied you health insurance',
#   'NEG'),
#  ('sex one those films that aims confuse', 'NEG'),
#  ('goes down easy leaving virtually aftertaste', 'POS'),
#  ('sunshine state surveys the landscape and assesses the issues with clear passion for sociology',
#   'NEG'),
#  ('never laugh out loud funny but frequently amusing', 'POS'),
#  ('one the best silly horror movies recent memory with some real shocks store for unwary viewers',
#   'POS'),
#  ('diggs and lathan are among the chief reasons brown sugar such sweet and sexy film',
#   'POS'),
#  ('polanski has found the perfect material with which address his own world war experience his signature style',
#   'POS'),
#  ('will earn her share the holiday box office pie although this movie makes one thing perfectly clear she pretty woman but she working girl',
#   'POS'),
#  ('takes you somewhere you re not likely have seen before but beneath the exotic surface lrb and exotic dancing rrb surprisingly old fashioned',
#   'POS'),
#  ('difficult imagine that more confused less interesting and more sloppily made film could possibly come down the road ',
#   'NEG'),
#  ('all the small moments and flashbacks n t add much more than trite observations the human condition',
#   'NEG'),
#  ('the film stagecrafts are intimate and therefore bolder than the otherwise calculated artifice that defines and overwhelms the film production design',
#   'NEG'),
#  ('definitely the guilty pleasure b movie category reign fire incredibly inane that laughingly enjoyable',
#   'POS'),
#  ('you could easily mistake for sketchy work in progress that was inexplicably rushed the megaplexes before its time',
#   'NEG'),
#  ('the filmmaker heart the right place ', 'NEG'),
#  ('question for philosophers not filmmakers all the filmmakers need engage audience',
#   'NEG'),
#  ('jacobi the most fluent actors given relatively dry material from nijinsky writings perform and the visuals even erotically frank ones become dullingly repetitive',
#   'NEG'),
#  (' really horrible drek', 'NEG'),
#  ('talk her not the perfect movie many have made out but still quite worth seeing',
#   'POS'),
#  ('minutes just zings along with vibrance and warmth', 'POS'),
#  ('surprises', 'NEG'),
#  ('rock solid gangster movie with fair amount suspense intriguing characters and bizarre bank robberies plus heavy dose father and son dynamics',
#   'POS'),
#  ('shot rich shadowy black and white devils chronicles with increasingly amused irony the relationship between reluctant captors and befuddled captives',
#   'POS'),
#  ('you ll cry for your money back', 'NEG'),
#  ('passable romantic comedy need another couple passes through the word processor',
#   'NEG'),
#  ('this stunning film one of a kind tour force', 'POS'),
#  ('allen shows can outgag any those young whippersnappers making moving pictures today',
#   'POS'),
#  ('lazy for movie avoid solving one problem trying distract with the solution another',
#   'NEG'),
#  ('smart funny and just honest enough provide the pleasures slightly naughty just above average off broadway play',
#   'POS'),
#  ('twohy good yarn spinner and ultimately the story compels', 'POS'),
#  ('this submarine drama earns the right favorably compared das boot', 'POS'),
#  ('quite achievement set and shoot movie the cannes film festival and yet fail capture its visual appeal its atmosphere',
#   'NEG'),
#  ('elegantly crafted but emotionally cold puzzle whose intricate construction one can admire but difficult connect with any deeper level',
#   'NEG'),
#  ('all about anakin and the lustrous polished visuals rich color and creativity and course special effect',
#   'POS'),
#  ('the film was n t preachy but was feminism the book', 'NEG'),
#  ('not single minded john carpenter original but sure lot smarter and more unnerving than the sequels',
#   'POS'),
#  ('despite the pyrotechnics narc strictly the book', 'NEG'),
#  ('predictable and cloying though brown sugar earnest its yearning for the days before rap went nihilistic that summons more spirit and bite than your average formulaic romantic quadrangle',
#   'POS'),
#  ('the star who helped give spark chasing amy and changing lanes falls flat thinking man cia agent jack ryan this summer new action film the sum all fears',
#   'NEG'),
#  ('too bad none funny', 'NEG'),
#  ('comedy troupe broken lizard first movie very funny but too concerned with giving plot',
#   'NEG'),
#  ('its treatment the dehumanizing and ego destroying process unemployment time out offers exploration that more accurate than anything have seen american film',
#   'POS'),
#  ('has all the right elements but completely fails gel together', 'NEG'),
#  ('you n t believe anyone would really buy this stuff', 'NEG'),
#  (' lrb rrb soulless stupid sequel ', 'NEG'),
#  ('just kiss wants desperately come off fanciful film about the typical problems average people',
#   'NEG'),
#  ('creaky staircase gothic', 'NEG'),
#  ('gently humorous and touching', 'POS'),
#  ('cho timing priceless', 'POS'),
#  (' guiltless film for nice evening out', 'POS'),
#  ('and the positive change tone here seems have recharged him', 'POS'),
#  (' lrb woo rrb most resonant film since the killer', 'POS'),
#  ('the success undercover brother found its ability spoof both black and white stereotypes equally',
#   'POS'),
#  ('the plot clearly mythic structure may owe more disney strong sense formula than the original story',
#   'NEG'),
#  ('lovably old school hollywood confection', 'POS'),
#  ('the series message about making the right choice the face tempting alternatives remains prominent the girls amusing personalities',
#   'POS'),
#  ('nijinsky says know how suffer and you see this film you ll know too',
#   'NEG'),
#  ('more trifle than triumph', 'NEG'),
#  ('snipes relies too much scorchingly plotted dramatic scenario for its own good',
#   'NEG'),
#  ('was impressed how many tit for tat retaliatory responses the filmmakers allow before pulling the plug the conspirators and averting american russian armageddon',
#   'POS'),
#  ('mildly entertaining especially you find comfort familiarity', 'POS'),
#  ('offers glimpse the solomonic decision facing jewish parents those turbulent times save their children and yet lose them',
#   'POS'),
#  ('sometimes makes less sense than the bruckheimeresque american action flicks emulates',
#   'NEG'),
#  ('handsome and sincere but slightly awkward its combination entertainment and evangelical boosterism',
#   'NEG'),
#  (' overly melodramatic ', 'NEG'),
#  ('the kind sweet and sour insider movie that film buffs will eat like much gelati',
#   'POS'),
#  ('preposterously melodramatic paean gang member teens brooklyn circa ',
#   'NEG'),
#  ('whether you like not basically matter taste', 'NEG'),
#  ('fluffy neo noir hiding behind cutesy film references', 'NEG'),
#  ('you are into splatter movies then you will probably have reasonably good time with the salton sea',
#   'POS'),
#  ('the predominantly amateur cast painful watch stilted and unconvincing are the performances',
#   'NEG'),
#  ('the engagingly primitive animated special effects contribute mood that sustained through the surprisingly somber conclusion',
#   'POS'),
#  ('did back and check out the last minutes but these were more repulsive than the first minutes',
#   'NEG'),
#  ('really quite funny', 'POS'),
#  ('sorority boys was funnier and that movie was pretty bad', 'NEG'),
#  ('takes clunky tv movie approach detailing chapter the life the celebrated irish playwright poet and drinker',
#   'NEG'),
#  ('executed with such gentle but insistent sincerity with such good humor and appreciation the daily grind that only the most hardhearted scrooge could fail respond',
#   'POS'),
#  ('dolman confines himself shtick and sentimentality the one bald and the other sloppy',
#   'NEG'),
#  ('you never know where changing lanes going take you but heck ride', 'POS'),
#  ('rich tale our times very well told with appropriate minimum means', 'POS'),
#  ('modestly surprising movie', 'POS'),
#  ('when compared the usual more somber festival entries davis highly personal brand romantic comedy tart smart breath fresh air that stands out from the pack even the picture itself somewhat problematic',
#   'POS'),
#  ('wewannour money back actually', 'NEG'),
#  ('the director many dodges and turns add little more than screenful gamesmanship that low both suspense and payoff',
#   'NEG'),
#  ('beautifully shot against the frozen winter landscapes grenoble and geneva the film unfolds with all the mounting tension expert thriller until the tragedy beneath all gradually reveals itself',
#   'POS'),
#  ('not good enough pass for litmus test the generation gap and not bad enough repulse any generation its fans',
#   'NEG'),
#  ('while the filmmaking may bit disjointed the subject matter fascinating that you n t care',
#   'POS'),
#  ('the story has its redundancies and the young actors not very experienced are sometimes inexpressive',
#   'NEG'),
#  ('entertaining british hybrid comedy caper thrills and quirky romance',
#   'POS'),
#  ('coarse cliched and clunky this trifling romantic comedy which opposites attract for better reason than that the screenplay demands squanders the charms stars hugh grant and sandra bullock',
#   'NEG'),
#  ('this one the biggest disappointments the year', 'NEG'),
#  ('one those films that seems tailor made air pay cable offer some modest amusements when one has nothing else watch',
#   'NEG'),
#  ('movie that about overbearing and over the top the family depicts', 'NEG'),
#  ('offers clear eyed chronicle female friendship that more complex and honest than anything represented hollywood film',
#   'POS'),
# ...
#   'POS'),
#  ('but the talented cast alone will keep you watching will the fight scenes',
#   'POS'),
#  ('presents good case while failing provide reason for care beyond the very basic dictums human decency',
#   'NEG'),
#  ('maybe how will you feel after minute rip off the rock with action confined slo mo gun firing and random glass shattering',
#   'NEG'),
#  ('what stiflingly unfunny and unoriginal mess this', 'NEG'),
#  ('though some ways similar catherine breillat fat girl rain the far superior film',
#   'POS'),
#  (' lrb davis rrb wants cause his audience epiphany yet refuses give real situations and characters',
#   'NEG'),
#  ('the film becomes overwhelming pleasure and you find yourself rooting for gai character avoid the fate that has befallen every other carmen before her',
#   'POS'),
#  ('ultimately sarah dedication finding her husband seems more psychotic than romantic and nothing the movie makes convincing case that one woman broken heart outweighs all the loss witness',
#   'NEG'),
#  ('blessed with searing lead performance ryan gosling lrb murder numbers rrb the movie powerful and provocative',
#   'POS'),
#  ('plot characters drama emotions ideas all are irrelevant the experience seeing the scorpion king',
#   'NEG'),
#  ('red dragon less baroque and showy than hannibal and less emotionally affecting than silence',
#   'NEG'),
#  ('confluence kiddie entertainment sophisticated wit and symbolic graphic design',
#   'POS'),
#  ('easily one the best and most exciting movies the year', 'POS'),
#  ('the movie messages are quite admirable but', 'NEG'),
#  ('from the opening strains the average white band pick the pieces you can feel the love',
#   'POS'),
#  ('purports hollywood satire but winds the kind film that should the target something deeper and more engaging',
#   'NEG'),
#  ('charlotte sometimes gem', 'POS'),
#  ('dong never pushes for insights beyond the superficial tensions the dynamic dissecting and the film settles too easily along the contours expectation',
#   'NEG'),
#  ('while obviously aimed kids the country bears should keep parents amused with its low groan to guffaw ratio',
#   'POS'),
#  ('this ready made midnight movie probably n t stand the cold light day but under the right conditions goofy lrb not entirely wholesome rrb fun',
#   'POS'),
#  ('not original enough', 'NEG'),
#  ('this christmas future for lot baby boomers', 'POS'),
#  ('what really happened', 'NEG'),
#  ('yes they can swim the title merely anne sophie birot off handed way saying girls find adolescence difficult wade through',
#   'NEG'),
#  ('from blushing gushing imamura squirts the screen warm water under red bridge',
#   'POS'),
#  ('one these days hollywood will come with original idea for teen movie but until then there always these rehashes feed the younger generations',
#   'NEG'),
#  ('schrader examines crane decline with unblinking candor', 'POS'),
#  ('with its jerky hand held camera and documentary feel bloody sunday sobering recount very bleak day derry',
#   'NEG'),
#  ('alarms for duvall throbbing sincerity and his elderly propensity for patting people while talks',
#   'POS'),
#  ('fine film but would lot better stuck betty fisher and left out the other stories',
#   'NEG'),
#  (' there choppy surface effect feeling the whole enterprise', 'NEG'),
#  ('the year old godard has become judge from praise love the sort bitter old crank who sits behind his light meter and harangues the supposed injustices the artistic world at large without doing all that much correct them',
#   'NEG'),
#  ('though this rude and crude film does deliver few gut busting laughs its digs modern society are all things ve seen before',
#   'NEG'),
#  ('try this obscenely bad dark comedy crass that makes edward burns sidewalks new york look like oscar wilde',
#   'NEG'),
#  ('about the hard partying', 'NEG'),
#  ('when mr hundert tells his narration that this story without surprises nod agreement',
#   'NEG'),
#  ('earnest roughshod document serves workable primer for the region recent history and would make terrific th grade learning tool',
#   'POS'),
#  ('the effort sincere and the results are honest but the film bleak that hardly watchable',
#   'NEG'),
#  ('wild endearing masterful documentary', 'POS'),
#  ('changing lanes tries for more', 'POS'),
#  ('the telling story largely untold bui chooses produce something that ultimately suspiciously familiar',
#   'NEG'),
#  ('rubbo runs through remarkable amount material the film short minutes',
#   'POS'),
#  ('what most memorable about circuit that shot digital video whose tiny camera enables shafer navigate spaces both large and small with considerable aplomb',
#   'POS'),
#  ('worth seeing once but its charm quickly fades', 'NEG'),
#  ('bland obnoxious minute infomercial for universal studios and its ancillary products',
#   'NEG'),
#  ('writer director juan carlos fresnadillo makes feature debut that fully formed and remarkably assured',
#   'POS'),
#  ('follows the blair witch formula for hour which re told something creepy and vague the works and then goes awry the final minutes',
#   'NEG'),
#  ('fun splashy and entertainingly nasty', 'POS'),
#  ('like mike slight and uninventive movie like the exalted michael jordan referred the title many can aspire but none can equal',
#   'NEG'),
#  ('time machine journey back your childhood when cares melted away the dark theater and films had the ability mesmerize astonish and entertain',
#   'POS'),
#  ('ludicrous but director carl franklin adds enough flourishes and freak outs make entertaining',
#   'POS'),
#  ('what more can expected from college comedy that target audience has n t graduated from junior high school',
#   'NEG'),
#  ('you saw benigni pinocchio public park you grab your kids and run and then probably call the police',
#   'NEG'),
#  ('treat watching shaw british stage icon melting under the heat phocion attentions',
#   'POS'),
#  ('has become apparent that the franchise best years are long past', 'NEG'),
#  ('the complex politically charged tapestry contemporary chinese life this exciting new filmmaker has brought the screen like nothing westerners have seen before',
#   'POS'),
#  ('compelling yarn but not quite ripping one', 'POS'),
#  ('the movie vision white american zealously spreading puritanical brand christianity south seas islanders one only true believer could relish',
#   'NEG'),
#  ('the issues are presented such lousy way complete with some the year lrb unintentionally rrb funniest moments that impossible care',
#   'NEG'),
#  ('while the story does seem pretty unbelievable times awfully entertaining watch',
#   'POS'),
#  ('one those movies that catches you something bigger than yourself namely archetypal desire enjoy good trash every now and then',
#   'POS'),
#  ('oscar caliber cast does n t live material', 'NEG'),
#  ('the problem with movies about angels they have tendency slip into hokum',
#   'NEG'),
#  ('the biggest problem have lrb other than the very sluggish pace rrb never really see her esther blossom actress even though her talent supposed growing',
#   'NEG'),
#  ('for all its plot twists and some them verge the bizarre the film winds down blood work strong character oriented piece',
#   'NEG'),
#  (' post september the sum all fears seems more tacky and reprehensible manipulating our collective fear without bestowing the subject with the intelligence sincerity unequivocally deserves',
#   'NEG'),
#  ('but what nice that there casual intelligence that permeates the script',
#   'POS'),
#  ('not particularly subtle however still manages build terrifying obvious conclusion',
#   'NEG'),
#  ('has plenty laughs', 'POS'),
#  ('the affable maid manhattan jennifer lopez most aggressive and most sincere attempt take movies storm the diva shrewdly surrounds herself with company strictly a list players',
#   'POS'),
#  ('when science fiction takes advantage the fact that its intended audience has n t yet had much science does disservice the audience and the genre',
#   'NEG'),
#  ('director elie chouraqui who co wrote the script catches the chaotic horror war but why bother you re going subjugate truth the tear jerking demands soap opera',
#   'NEG'),
#  ('yes suppose lovely that cal works out his issues with his dad and comes terms with his picture perfect life but world traveler gave reason care did n t',
#   'NEG'),
#  ('this smart movie that knows its classical music knows its freud and knows its sade',
#   'POS'),
#  ('bad sign when you re rooting for the film hurry and get its subjects deaths just the documentary will over but indicative how uncompelling the movie unless happens cover your particular area interest',
#   'NEG'),
#  (' powerful sequel and one the best films the year', 'POS'),
#  ('has enough wit energy and geniality please not only the fanatical adherents either side but also people who know nothing about the subject and think they re not interested',
#   'POS'),
#  ('tykwer surface flash n t just poor fit with kieslowski lyrical pessimism completely contradicts everything kieslowski work aspired including the condition art',
#   'NEG'),
#  (' once the true impact the day unfolds the power this movie undeniable',
#   'POS'),
#  ('both exuberantly romantic and serenely melancholy what time there', 'POS'),
#  ('wildly incompetent but brilliantly named half past dead for seagal pessimists totally past his prime',
#   'NEG'),
#  ('the history fascinating the action dazzling', 'POS'),
#  ('hope keeps arising that the movie will live the apparent skills its makers and the talents its actors but does n t',
#   'NEG'),
#  ('has all the complexity and realistic human behavior episode general hospital',
#   'NEG'),
#  ('the sound gunfire and cell phones ringing', 'NEG'),
#  ('think gidget only with muscles and lot more smarts but just endearing and easy watch',
#   'POS'),
#  ('beresford nicely mixes much humor pathos take his sentimental journey the heart',
#   'POS'),
#  ('impostor n t think thing with these characters except have them run through dark tunnels fight off various anonymous attackers and evade elaborate surveillance technologies',
#   'NEG'),
#  ('mark pellington latest pop thriller kooky and overeager spooky and subtly love with myth',
#   'POS'),
#  ('its spirit iconoclastic abandon however canned makes for unexpectedly giddy viewing',
#   'POS'),
#  ('deliberately and devotedly constructed far from heaven too picture postcard perfect too neat and new pin like too obviously recreation resonate',
#   'POS'),
#  ('the movie captivating details are all the performances from foreman barking mad taylor thewlis smoothly sinister freddie and bettany mcdowell hard eyed gangster',
#   'POS'),
#  ('perfectly acceptable perfectly bland competently acted but means scary horror movie',
#   'NEG'),
#  ('entirely suspenseful extremely well paced and ultimately dare say entertaining',
#   'POS'),
#  ('one look girl tight pants and big tits and you turn stupid', 'NEG'),
#  ('who exactly fighting whom here', 'NEG'),
#  ('dim witted and lazy spin off the animal planet documentary series crocodile hunter entertainment opportunism its most glaring',
#   'NEG'),
#  ('waterlogged version fatal attraction for the teeny bopper set sad soggy potboiler that wastes the talents its attractive young leads',
#   'NEG'),
#  ('and adults will least have dream image the west savor whenever the film lamer instincts are the saddle',
#   'NEG'),
#  ('strange way egoyan has done too much', 'NEG'),
#  ('big corner office hell satan throwing his hands surrender firing his r d people and has decided will just screen the master disguise ',
#   'NEG'),
#  ('astonishing lrb frames rrb profound ethical and philosophical questions the form dazzling pop entertainment',
#   'POS'),
#  ('what sets ms birot film apart from others the genre greater attention the parents and particularly the fateful fathers the emotional evolution the two bewitched adolescents',
#   'POS'),
#  (' lrb rrb smarter and much funnier version the old police academy flicks',
#   'POS'),
#  ('boasts enough funny dialogue and sharp characterizations mildly amusing',
#   'POS'),
#  ('well executed spy thriller', 'POS'),
#  ('the attempt complicate the story only defies credibility', 'NEG'),
#  ('you re happy listening movies you are watching them and the slow parade human frailty fascinates you then you re the right film',
#   'POS'),
#  ('though lan lacks sense dramatic urgency the film makes for with pleasing verisimilitude',
#   'POS'),
#  (' another example how sandler losing his touch', 'NEG'),
#  ('ozpetek effort has the scope and shape especially well executed television movie',
#   'POS'),
#  ('difficult discern this crazy work disturbed genius merely minutes post adolescent electra rebellion',
#   'NEG'),
#  ('little more intensity and little less charm would have saved this film world hurt',
#   'NEG'),
#  ('drumline ably captures the complicated relationships marching band', 'POS'),
#  ('been there done that liked much better the first time around when was called the professional',
#   'NEG'),
#  ('entertainment destination for the general public kung pow sets new benchmark for lameness',
#   'NEG'),
#  ('promises one film that truly deserving its oscar nomination', 'POS'),
#  ('works well enough since the thrills pop frequently and the dispatching the cast often imaginative gory',
#   'POS'),
#  ('arteta paints picture lives lived state quiet desperation', 'POS'),
#  ('has affect the kurds but wore down', 'NEG'),
#  ('its best which occurs often michael moore bowling for columbine rekindles the muckraking soul searching spirit the are sick society',
#   'POS'),
#  ('ice age the first computer generated feature cartoon feel like other movies and that makes for some glacial pacing early',
#   'NEG'),
#  ('the increasingly diverse french director has created film that one can honestly describe looking sounding and simply feeling like other film recent history',
#   'POS'),
#  ('however sincere may the rising place never quite justifies its own existence',
#   'NEG'),
#  ('watching ending too often like looking over the outdated clothes and plastic knickknacks your neighbor garage sale',
#   'NEG'),
#  ('cold nervy and memorable', 'POS'),
#  ('no ', 'NEG'),
#  ('coupling disgracefully written dialogue with flailing bodily movements that substitute for acting circuit the awkwardly paced soap opera ish story',
#   'NEG'),
#  ('glorious mess', 'NEG'),
#  ('heartbreakingly thoughtful minor classic the work genuine and singular artist',
#   'POS'),
#  ('smart steamy mix road movie coming of age story and political satire',
#   'POS'),
#  ('culture clash comedy only half clever thinks', 'NEG'),
#  ('film really has exceptional justify three hour running time and this n t',
#   'NEG'),
#  ('the bottom line least opinion imposter makes better short story than does film',
#   'NEG'),
#  ('for every articulate player such skateboarder tony hawk bmx rider mat hoffman are about half dozen young turks angling see how many times they can work the words radical suck into sentence',
#   'NEG'),
#  ('hopelessly inane humorless and under inspired', 'NEG'),
#  ('like veteran head cutter barbershop tuned its community', 'POS'),
#  ('daringly perceptive taut piercing and feisty biggie and tupac undeniably subversive and involving its bold presentation',
#   'POS'),
#  ('nothing short wonderful with its ten year old female protagonist and its steadfast refusal set dualistic battle between good and evil',
#   'POS'),
#  ('gosling creates staggeringly compelling character young man whose sharp intellect the very root his contradictory self hating self destructive ways',
#   'POS'),
#  ('driven fantastic dual performance from ian holm the film funny insightfully human and delightful lark for history buffs',
#   'POS'),
#  ('aniston has last decisively broken with her friends image independent film satiric fire and emotional turmoil',
#   'POS'),
#  ('count his movie work the back your neck long after you leave the theater',
#   'NEG'),
#  ('few the increasingly far fetched events that first time writer director neil burger follows with are terribly convincing which pity considering barry terrific performance',
#   'NEG'),
#  ('all pretty tame', 'NEG'),
#  ('not generally huge fan cartoons derived from shows but hey arnold', 'POS'),
#  ...]

# %%
valid_data=list(zip(x_valid,y_valid))
valid_data
# Out:
# [('compassionate moving portrait american lrb and america rrb always reaching for something just outside his grasp',
#   'POS'),
#  ('this story still seems timely and important', 'POS'),
#  ('rewarding', 'POS'),
#  ('probes light hearted way the romantic problems individuals for whom the yearning for passion spells discontent',
#   'POS'),
#  ('all three actresses are simply dazzling particularly balk who finally been given part worthy her considerable talents',
#   'POS'),
#  ('when not wallowing hormonal melodrama real women have curves sweet honest and enjoyable comedy drama about young woman who wants many things life but fears she ll become her mother before she gets fulfill her dreams',
#   'POS'),
#  ('lot more dimensional and complex than its sunny disposition would lead you believe',
#   'POS'),
#  ('superbly photographed and staged mendes with series riveting set pieces the likes which mainstream audiences have rarely seen',
#   'POS'),
#  ('all all reign fire will good lrb successful rrb rental', 'NEG'),
#  ('nothing but one relentlessly depressing situation after another for its entire running time something that you could easily dealing with right now your lives',
#   'NEG'),
#  ('only two fifths satisfying movie experience', 'NEG'),
#  ('director chris wedge and screenwriters michael berg michael wilson and peter ackerman create some episodes that rival vintage looney tunes for the most creative mayhem brief amount time',
#   'POS'),
#  ('enormously entertaining movie like nothing ve ever seen before and yet completely familiar',
#   'POS'),
#  ('engages constant fits laughter until find ourselves surprised how much care about the story and end walking out not only satisfied but also somewhat touched',
#   'POS'),
#  (' lrb rrb stuporously solemn film', 'NEG'),
#  ('directed with purpose and finesse england roger mitchell who handily makes the move from pleasing relatively lightweight commercial fare such notting hill commercial fare with real thematic heft',
#   'POS'),
#  ('the wonder mostly martha the performance gedeck who makes martha enormously endearing',
#   'POS'),
#  ('where their heads were anyone guess', 'NEG'),
#  ('refreshing change from the usual whoopee cushion effort aimed the youth market',
#   'POS'),
#  ('blue crush predictable the tides', 'NEG'),
#  ('outside burger desire make some kind film really unclear why this project was undertaken',
#   'NEG'),
#  ('wild ride juiced with enough energy and excitement for least three films',
#   'POS'),
#  ('memorable for peculiar malaise that renders its tension flaccid and extension its surprises limp and its resolutions ritual',
#   'NEG'),
#  ('one the most important and exhilarating forms animated filmmaking since old walt doodled steamboat willie',
#   'POS'),
#  ('this truly truly bad movie', 'NEG'),
#  ('bears even worse than imagined movie ever could', 'NEG'),
#  ('cacoyannis vision far less mature interpreting the play call for pity and sympathy for anachronistic phantasms haunting the imagined glory their own pasts',
#   'NEG'),
#  ('don michael paul uses quick cuts lrb very rrb large shadows and wide angle shots taken from distance hide the liberal use body double lrb for seagal rrb ',
#   'NEG'),
#  ('you can practically hear george orwell turning over', 'NEG'),
#  ('will you ape over this movie', 'NEG'),
#  ('spielberg first real masterpiece deserved all the hearts won and wins still years later',
#   'POS'),
#  ('muccino who directed from his own screenplay canny crowd pleaser and the last kiss provides more than enough sentimental catharsis for satisfying evening the multiplex',
#   'POS'),
#  ('suffers from flat script and low budget', 'NEG'),
#  ('spectacular performance ahem hope only acting', 'POS'),
#  ('this follow up seems similar the disney classic that makes one long for geriatric peter',
#   'NEG'),
#  ('while there likely very little crossover appeal those without much interest the elizabethans lrb well rank frustration from those the know about rubbo dumbed down tactics rrb much ado about something amicable endeavor',
#   'POS'),
#  ('one just waits grimly for the next shock without developing much attachment the characters',
#   'NEG'),
#  ('those seeking definitive account eisenstein life would better elsewhere',
#   'NEG'),
#  ('once folks started hanging out the barbershop they never wanted leave',
#   'POS'),
#  ('genuinely unnerving', 'POS'),
#  ('there subversive element this disney cartoon providing unexpected fizzability',
#   'POS'),
#  ('the script smart and dark hallelujah for small favors', 'POS'),
#  ('sinks into the usual cafeteria goulash fart jokes masturbation jokes and racist japanese jokes',
#   'NEG'),
#  ('definitely not made for kids their parents for that matter and think even fans sandler comic taste may find uninteresting',
#   'NEG'),
#  ('the movie brilliant really', 'POS'),
#  ('there thin line between likably old fashioned and fuddy duddy and the count monte cristo never quite settles either side',
#   'NEG'),
#  ('the fourth pokemon diverting predictable adventure suitable for matinee with message that cautions children about disturbing the world delicate ecological balance',
#   'POS'),
#  ('about enjoyable would imagine searching for quarter giant pile elephant feces positively dreadful',
#   'NEG'),
#  ('art house the core read lips genre curling crime story that revives the free wheeling noir spirit old french cinema',
#   'POS'),
#  ('have returned from the beyond warn you this movie minutes long and life too short',
#   'NEG'),
#  ('nemesis suffers from paunchy midsection several plodding action sequences and wickedly undramatic central theme',
#   'NEG'),
#  ('some writer dude think his name was michael zaidan was supposed have like written the screenplay something but dude the only thing that ever saw that was written down were the zeroes paycheck',
#   'NEG'),
#  ('once emotional and richly analytical the cosby seinfeld encounter alone confirms the serious weight behind this superficially loose larky documentary',
#   'NEG'),
#  ('boy boy howler', 'NEG'),
#  ('and educational', 'POS'),
#  ('film with idea buried somewhere inside its fabric but never clearly seen felt',
#   'NEG'),
#  ('like its parade predecessors this halloween gory slash fest', 'POS'),
#  ('the weird thing about the santa clause purportedly children movie that there nothing engage children emotionally',
#   'NEG'),
#  (' lrb seagal rrb strenuous attempt change expression could very well clinch him this year razzie',
#   'NEG'),
#  ('the performances are all solid merely lacks originality make great movie',
#   'NEG'),
#  ('sustained fest self congratulation between actor and director that leaves scant place for the viewer',
#   'NEG'),
#  ('just plain bad', 'NEG'),
#  ('the story gives ample opportunity for large scale action and suspense which director shekhar kapur supplies with tremendous skill',
#   'POS'),
#  ('weaver and lapaglia are both excellent the kind low key way that allows forget that they are actually movie folk',
#   'POS'),
#  ('watching queen the damned like reading research paper with special effects tossed',
#   'NEG'),
#  ('bittersweet drama about the limbo grief and how truth telling can open the door liberation',
#   'POS'),
#  ('ending', 'NEG'),
#  ('not even solondz thirst for controversy sketchy characters and immature provocations can fully succeed cheapening',
#   'NEG'),
#  ('the director mostly plays straight turning leys fable into listless climb down the social ladder',
#   'NEG'),
#  ('once again the intelligence gay audiences has been grossly underestimated and meaty plot and well developed characters have been sacrificed for skin and flash that barely fizzle',
#   'NEG'),
#  ('lively account seinfeld deadpan', 'NEG'),
#  ('made feel uneasy even queasy because lrb solondz rrb cool compassion the border bemused contempt',
#   'NEG'),
#  ('bad sign thriller when you instantly know whodunit', 'NEG'),
#  ('you re looking for intelligent movie which you can release your pent anger enough just the ticket you need',
#   'POS'),
#  ('being unique does n t necessarily equate being good matter how admirably the filmmakers have gone for broke',
#   'NEG'),
#  ('exceptionally well acted diane lane and richard gere', 'POS'),
#  ('girls right down the reality drain', 'NEG'),
#  ('living testament the power the eccentric and the strange', 'POS'),
#  ('shiner can certainly the distance but n t world championship material',
#   'POS'),
#  ('stylishly directed with verve ', 'POS'),
#  ('why sit through crummy wannabe hip crime comedy that refers incessantly old movies when you could just rent those movies instead let alone seek out respectable new one',
#   'NEG'),
#  ('nettelbeck has crafted engaging fantasy flavours and emotions one part romance novel one part recipe book',
#   'POS'),
#  ('mama africa pretty much delivers that promise', 'POS'),
#  ('n t blame eddie murphy but should n t owen wilson know movie must have story and script',
#   'NEG'),
#  ('ash wednesday not edward burns best film but good and ambitious film',
#   'POS'),
#  ('much about the film loopy and ludicrous that could have been hoot bad movie way the laborious pacing and endless exposition had been tightened',
#   'NEG'),
#  ('the script dim witted pairing teen speak and animal gibberish', 'NEG'),
#  ('uneven self conscious but often hilarious spoof', 'POS'),
#  ('stylistic romp that always fun watch', 'POS'),
#  (' complete shambles movie sloppy uneven damn unpleasant that n t believe any viewer young old would have good time here',
#   'NEG'),
#  ('synthetic the best description this well meaning beautifully produced film that sacrifices its promise for high powered star pedigree',
#   'NEG'),
#  ('upsetting and thought provoking the film has odd purity that does n t bring you into the characters much has you study them',
#   'POS'),
#  ('charlize chases kevin with gun', 'NEG'),
#  ('eloquent reflective and beautifully acted meditation both the profoundly devastating events one year ago and the slow painful healing process that has followed their wake',
#   'POS'),
#  ('family portrait need neurosis and nervy negativity rare treat that shows the promise digital filmmaking',
#   'POS'),
#  ('the performances the four main actresses bring their characters life',
#   'POS'),
#  ('hard imagine that even very small children will impressed this tired retread',
#   'NEG'),
#  ('director chef gabriele muccino keeps fast zippy comin fearing that his film molto superficiale',
#   'NEG'),
#  ('there are n t many conclusive answers the film but there interesting story pointed personalities courage tragedy and the little guys vs the big guys',
#   'POS'),
#  ('gangster movie with the capacity surprise', 'POS'),
#  ('there welcome lack pretension about the film which very simply sets out entertain and ends delivering good measure',
#   'POS'),
#  ('transforms one lrb shakespeare rrb deepest tragedies into smart new comedy',
#   'POS'),
#  ('bilingual charmer just like the woman who inspired', 'POS'),
#  ('combine the paranoid claustrophobia submarine movie with the unsettling spookiness the supernatural why did n t hollywood think this sooner',
#   'POS'),
#  ('never dull and always looks good', 'POS'),
#  ('instantly forgettable snow and stuntwork extravaganza that likely will upstaged avalanche more appealing holiday season product',
#   'NEG'),
#  ('what dumb fun curiously adolescent movie this', 'POS'),
#  ('more the same old garbage hollywood has been trying pass off acceptable teen entertainment for some time now',
#   'NEG'),
#  ('temporal inquiry that shoulders its philosophical burden lightly', 'POS'),
#  ('some people march the beat different drum and you ever wondered what kind houses those people live this documentary takes look alternative housing options',
#   'POS'),
#  ('invaluable historical document thanks the filmmaker extraordinary access massoud whose charm cultivation and devotion his people are readily apparent',
#   'POS'),
#  ('something for everyone', 'POS'),
#  ('the entire movie has truncated feeling but what available lovely and lovable',
#   'NEG'),
#  ('suffice say its total promise left slightly unfulfilled', 'NEG'),
#  ('strange funny twisted brilliant and macabre', 'POS'),
#  ('characterisation has been sacrificed for the sake spectacle', 'NEG'),
#  ('the movie progression into rambling incoherence gives new meaning the phrase fatal script error',
#   'NEG'),
#  ('gives poor dana carvey nothing that really funny and then expects laugh because acts goofy all the time',
#   'NEG'),
#  ('the sinister inspiration that fuelled devito early work confused death smoochy into something both ugly and mindless',
#   'NEG'),
#  ('mctiernan remake may lighter its feet the sober minded original was graceful tap dancing rhino but just boring and obvious',
#   'NEG'),
#  ('both shrill and soporific and because everything repeated five six times can seem tiresomely simpleminded',
#   'NEG'),
#  ('though frida easier swallow than julie taymor preposterous titus the eye candy here lacks considerable brio',
#   'NEG'),
#  ('too many improbabilities and rose colored situations temper what could ve been impacting film',
#   'NEG'),
#  ('another boorish movie from the i heard a joke at a frat party school screenwriting',
#   'NEG'),
#  ('leers offering next little insight into its intriguing subject', 'NEG'),
#  ('becomes the last thing you would expect from film with this title indeed from any plympton film boring',
#   'NEG'),
#  ('proves that some movie formulas n t need messing with like the big bug movie',
#   'NEG'),
#  ('good performances keep from being total rehash', 'POS'),
#  ('refreshingly realistic affectation free coming of age tale', 'POS'),
#  ('only about sexy and dangerous actress role that reminds every turn elizabeth berkley flopping dolphin gasm',
#   'NEG'),
#  ('less than fresh', 'NEG'),
#  ('this one baaaaaaaaad movie', 'NEG'),
#  ('the first fatal attraction was vile enough', 'NEG'),
#  ('small gem movie that defies classification and thought provoking funny scary and sad',
#   'POS'),
#  ('films about loss grief and recovery are pretty valuable these days', 'POS'),
#  ('depicts the sorriest and most sordid human behavior the screen then laughs how clever being',
#   'NEG'),
#  ('the overall result intelligent realistic portrayal testing boundaries',
#   'POS'),
#  ('anyone with passion for cinema and indeed sex should see soon possible',
#   'POS'),
#  ('even that too committed', 'NEG'),
#  ('the fluid motion astounding any number levels', 'POS'),
#  ('narc all menace and atmosphere', 'NEG'),
#  ('but this new jangle noise mayhem and stupidity must serious contender for the title',
#   'NEG'),
#  ('consistently clever and suspenseful', 'POS'),
#  ('baffling mixed platter gritty realism and magic realism with hard to swallow premise',
#   'NEG'),
#  ('though there clarity purpose and even handedness the film direction the drama feels rigged and sluggish',
#   'NEG'),
#  ('unencouraging threefold expansion the former mtv series accompanying the stunt hungry dimwits random series collected gags pranks pratfalls dares injuries etc ',
#   'NEG'),
#  ('the screenplay hugely overwritten with tons and tons dialogue most given children',
#   'NEG'),
#  ('this fascinating film because there clear cut hero and all out villain',
#   'POS'),
#  ('exactly the kind movie toback detractors always accuse him making', 'NEG'),
#  ('happily stays close the ground spare and simple manner and does n t pummel with phony imagery music',
#   'POS'),
#  ('live wire film that never loses its ability shock and amaze', 'POS'),
#  ('masterpiece', 'POS'),
#  ('murderous maids pulls punches its depiction the lives the papin sister and the events that led their notorious rise infamy ',
#   'POS'),
#  ('worthwhile documentary whether you re into rap not even may still leave you wanting more answers the credits roll',
#   'POS'),
#  ('this minute movie only has about minutes decent material', 'NEG'),
#  ('you want call domino', 'NEG'),
#  ('this deeply spiritual film taps into the meaning and consolation afterlife communications',
#   'POS'),
#  ('broder screenplay shallow offensive and redundant with pitifully few real laughs',
#   'NEG'),
#  ('there beautiful aching sadness all', 'POS'),
#  ('like christmas movies with more elves and snow and less pimps and', 'NEG'),
#  ('the unexpected thing that its dying this shower black and white psychedelia quite beautiful',
#   'POS'),
#  ('one the best looking and stylish animated movies quite while ', 'POS'),
#  ('actually too sincere the crime movie equivalent chick flick', 'NEG'),
#  ('even the summertime the most restless young audience deserves the dignity action hero motivated something more than franchise possibilities',
#   'NEG'),
#  ('its own way', 'NEG'),
#  ('highly recommended engrossing story about horrifying historical event and the elements which contributed',
#   'POS'),
#  ('the immersive powers the giant screen and its hyper realistic images are put perfect use the breathtakingly beautiful outer space documentary space station',
#   'POS'),
#  ('despite its promising cast characters big trouble remains loosely tied series vignettes which only prove that zany does n t necessarily mean funny',
#   'NEG'),
#  ('one those terrific documentaries that collect bunch people who are enthusiastic about something and then figures out how make share their enthusiasm',
#   'POS'),
#  ('the main story compelling enough but difficult shrug off the annoyance that chatty fish',
#   'NEG'),
#  ('light the candles bring out the cake and n t fret about the calories because there precious little substance birthday girl simply and surprisingly nice light treat',
#   'POS'),
#  ('made unintentionally famous the queasy stomached critic who staggered from the theater and blacked out the lobby',
#   'NEG'),
#  ('adam sandler crazy nights wasted minutes sandler the voice over hero columbia pictures perverse idea animated holiday movie',
#   'NEG'),
#  ('tian emphasizes the isolation these characters confining color liyan backyard',
#   'NEG'),
#  (' cinematic disaster inadvertently sidesplitting worth the price admission for the ridicule factor alone',
#   'NEG'),
#  ('though uniformly well acted especially young ballesta and galan lrb first time actor rrb writer director achero manas film schematic and obvious',
#   'NEG'),
#  ('the bottom line with nemesis the same has been with all the films the series fans will undoubtedly enjoy and the uncommitted need n t waste their time',
#   'POS'),
#  ('anyone who wants start writing screenplays can just follow the same blueprint from hundreds other films sell the highest bidder and walk away without anyone truly knowing your identity',
#   'NEG'),
#  ('since the movie based nicholas sparks best seller you know death lurking around the corner just waiting spoil things',
#   'NEG'),
#  ('not bad but not all that good', 'NEG'),
#  ('using endearing cast writer director dover kosashvili takes slightly dark look relationships both sexual and kindred',
#   'POS'),
#  (' lrb city rrb reminds how realistically nuanced robert niro performance can when not more lucratively engaged the shameless self caricature analyze this lrb rrb and analyze that promised lrb threatened rrb for later this year',
#   'POS'),
#  ('there are deeply religious and spiritual people this world who would argue that entering church synagogue temple does n t mean you have check your brain the door',
#   'POS'),
#  ('the project filmmakers forgot include anything even halfway scary they poorly rejigger fatal attraction into high school setting',
#   'NEG'),
#  ('unorthodox little film noir organized crime story that includes one the strangest love stories you will ever see',
#   'POS'),
#  ('not only charming funny and beautifully crafted import uses very little dialogue making relatively effortless read and follow the action the same time',
#   'POS'),
#  ('parts', 'NEG'),
#  ('when the screenwriter responsible for one the worst movies one year directs equally miserable film the following year you have hard time believing was just coincidence',
#   'NEG'),
#  ('egoyan work often elegantly considers various levels reality and uses shifting points view but here has constructed film labyrinthine that defeats his larger purpose',
#   'NEG'),
#  ('instead ll only put you sleep', 'NEG'),
#  ('serious and thoughtful', 'POS'),
#  ('good actors have radar for juicy roles there plethora characters this picture and not one them flat',
#   'POS'),
#  ('the salton sea has moments inspired humour though every scrap the darkest variety',
#   'POS'),
#  ('vividly conveys the shadow side the year friendship between two english women',
#   'NEG'),
#  ('most the film feels conceived and shot the fly like between lunch breaks for shearer radio show and his simpson voice overs',
#   'NEG'),
#  ('funny sexy devastating and incurably romantic', 'POS'),
#  ('this feature about necessary hole the head', 'NEG'),
#  ('first timer john mckay never able pull back course', 'NEG'),
#  ('fast paced glitzy but extremely silly piece', 'NEG'),
#  ('ambitiously naturalistic albeit half baked drama about abused inner city autistic teen',
#   'POS'),
#  ('ultimate ride basically the kind greatest hits reel that might come with subscription espn the magazine',
#   'NEG'),
#  ('you see robin williams and psycho killer and you think hmmmmm', 'NEG'),
#  ('you leave feeling like you ve endured long workout without your pulse ever racing',
#   'NEG'),
#  ('but warned you too may feel time has decided stand still', 'NEG'),
#  ('like life the island the movie grows boring despite the scenery', 'NEG'),
#  ('left with the visceral sensation longing lasting traces charlotte web desire and desperation',
#   'POS'),
#  ('one the very best movies ever made about the life moviemaking', 'POS'),
#  ('n t scary', 'NEG'),
#  ('content merely lionize its title character and exploit his anger all for easy sanctimony formulaic thrills and ham fisted sermon the need for national health insurance',
#   'NEG'),
#  (' minute sample puerile rubbish that listless witless and devoid anything resembling humor',
#   'NEG'),
#  ('the only pain you ll feel the credits roll your stomach grumbling for some tasty grub',
#   'NEG'),
#  (' enjoyably frothy date movie ', 'POS'),
#  ('like comedian who starts off promisingly but then proceeds flop comedian runs out steam after half hour',
#   'NEG'),
#  ('these people are really going love the piano teacher', 'POS'),
#  ('the film was immensely enjoyable thanks great performances both steve buscemi and rosario dawson ',
#   'POS'),
#  ('your taste for jonah veggie tales movie may well depend your threshold for pop manifestations the holy spirit',
#   'NEG'),
#  ('the cinematic equivalent patronizing bar favored pretentious untalented artistes who enjoy moaning about their cruel fate',
#   'NEG'),
#  ('stevens vibrant creative instincts are the difference between this and countless other flicks about guys and dolls',
#   'POS'),
#  ('exploitative and largely devoid the depth sophistication that would make watching such graphic treatment the crimes bearable',
#   'NEG'),
#  ('late marriage in your face family drama and black comedy that filled with raw emotions conveying despair and love',
#   'POS'),
#  ('expands the limits what film can taking into the lives women whom might not give second look passed them the street',
#   'POS'),
#  ('there much tongue cheek the film and there doubt the filmmaker having fun with all',
#   'POS'),
#  ('nakata technique imply terror suggestion rather than the overuse special effects',
#   'POS'),
#  ('dong shows how intolerance has the power deform families then tear them apart',
#   'NEG'),
#  ('there greatness here', 'POS'),
#  ('when the twist endings were actually surprising', 'NEG'),
#  ('despite terrific special effects and funnier gags harry potter and the chamber secrets finds way make j k rowling marvelous series into deadly bore',
#   'NEG'),
#  ('imagine kevin smith the blasphemous bad boy suburban jersey were stripped most his budget and all his sense humor',
#   'NEG'),
#  ('the scariest guy you ll see all summer', 'POS'),
#  ('too bad', 'NEG'),
#  ('this mostly well constructed fluff which all seems intended', 'NEG'),
#  ('this in depth study important developments the computer industry should make required viewing university computer science departments for years come',
#   'POS'),
#  ('how inept serving sara', 'NEG'),
#  ('children and adults enamored all things pokemon n t disappointed', 'POS'),
#  ('the movie plot almost entirely witless and inane carrying every gag two three times beyond its limit sustain laugh',
#   'NEG'),
#  ('god help but capra and cooper are rolling over their graves', 'NEG'),
#  ('you re burnt out wonderful life marathons and bored with christmas carol might just the movie you re looking for',
#   'POS'),
#  (' feels lrb there rrb choke leash around your neck director nick cassavetes can give good hard yank whenever wants you feel something',
#   'NEG'),
#  ('movie that will wear you out and make you misty even when you n t want',
#   'NEG'),
#  ('walked away from this new version e t just hoped would with moist eyes',
#   'POS'),
#  ('horrendously amateurish filmmaking that plainly dull and visually ugly when n t incomprehensible',
#   'NEG'),
#  ('mr goyer loose unaccountable direction technically sophisticated the worst way',
#   'NEG'),
#  ('what you expect just what you get assuming the bar expectations has n t been raised above sixth grade height',
#   'NEG'),
#  ('can safely recommended video dvd babysitter', 'POS'),
#  ('wins vote for the enemy cinema award', 'NEG'),
#  ('energizing intoxicating documentary charting the rise hip hop culture general and the art scratching lrb turntablism rrb particular',
#   'POS'),
#  ('drug abuse infidelity and death are n t usually comedy fare but turpin film allows chuckle through the angst',
#   'POS'),
#  ('completely awful iranian drama much fun grouchy ayatollah cold mosque',
#   'NEG'),
#  ('hoffman waits too long turn his movie unexpected direction and even then his tone retains genteel prep school quality that feels dusty and leatherbound',
#   'NEG'),
#  ('your nightmares the other hand will anything but', 'NEG'),
#  ('innocuous enough make even jean claude van damme look good', 'NEG'),
#  ('riveting profile law enforcement and visceral nasty journey into urban hades',
#   'POS'),
#  ('wraps classic mother daughter struggle recycled paper with shiny new bow and while the audience can tell not all new least looks pretty',
#   'NEG'),
#  ('another retelling alexandre dumas classic', 'NEG'),
#  ('fortunately you still have that option', 'NEG'),
#  ('xxx diesel that rare creature action hero with table manners and one who proves that elegance more than tattoo deep',
#   'POS'),
#  ('great fun both for sports aficionados and for ordinary louts whose idea exercise climbing the steps stadium seat megaplex',
#   'POS'),
#  ('phoned in business usual', 'NEG'),
#  ('singularly off putting romantic comedy', 'NEG'),
#  ('downbeat period perfect biopic hammers home heavy handed moralistic message',
#   'POS'),
#  ('simone not bad film', 'POS'),
#  ('director juan jose campanella could have turned this into argentine retread iris american beauty but instead pulls little from each film and creates something more beautiful than either those films',
#   'POS'),
#  ('simply and eloquently articulates the tangled feelings particular new yorkers deeply touched unprecedented tragedy',
#   'POS'),
#  ('this slender plot feels especially thin stretched over the nearly minute running time',
#   'NEG'),
#  ('going give marginal thumbs', 'POS'),
#  ('what the most positive thing that can said about the new rob schneider vehicle',
#   'NEG'),
#  ('our culture headed down the toilet with the ferocity frozen burrito after all night tequila bender and know this because ve seen jackass the movie',
#   'NEG'),
#  ('they good job painting this family dynamic for the audience but they tried squeeze too many elements into the film',
#   'NEG'),
#  ('typically observant carefully nuanced and intimate french coming of age film that encouraging debut feature but has needlessly downbeat ending that too heavy for all that has preceded',
#   'NEG'),
#  ('while interesting witness the conflict from the palestinian side longley film lacks balance and fails put the struggle into meaningful historical context',
#   'NEG'),
#  ('playful iranian parable about openness particularly the need for people diverse political perspectives get along despite their ideological differences',
#   'POS'),
#  ('just collection this and that whatever fills time with unified whole',
#   'NEG'),
#  ('welles groupie scholar peter bogdanovich took long time but finally provided his own broadside publishing giant william randolph hearst',
#   'POS'),
#  ('anyone else who may for whatever reason thinking about going see this movie hereby given fair warning',
#   'NEG'),
#  ('although the sequel has all the outward elements the original the first film lovely flakiness gone replaced the forced funniness found the dullest kiddie flicks',
#   'NEG'),
#  ('were any more turkey would gobble dolby digital stereo', 'NEG'),
#  ('one the most gloriously unsubtle and adrenalized extreme shockers since the evil dead',
#   'POS'),
#  ('solondz intent hammering home his message that forgets make entertaining',
#   'NEG'),
#  ('far away', 'NEG'),
#  ('although pastry violated this nasty comedy pokes fun the same easy targets other rowdy raunch fests farts boobs unmentionables without much success',
#   'NEG'),
#  ('barely manages for but few seconds over its seemingly eternal running time pique your interest your imagination your empathy anything really save your disgust and your indifference',
#   'NEG'),
#  ('steadfastly uncinematic but powerfully dramatic', 'POS'),
#  ('there bit thematic meat the bones queen the damned its origins anne rice novel dictate but generally movie that emphasizes style over character and substance',
#   'NEG'),
#  ('must see for all sides the political spectrum', 'POS'),
#  ('clumsy obvious preposterous the movie will likely set the cause woman warriors back decades',
#   'NEG'),
#  ('australian filmmaker david flatman uses the huge screen format make old fashioned nature film that educates viewers with words and pictures while entertaining them',
#   'POS'),
#  ('releasing film with the word dog its title january lends itself easy jokes and insults and snow dogs deserves every single one them',
#   'NEG'),
#  ('engrossing and grim portrait hookers what they think themselves and their clients',
#   'POS'),
#  ('banal the telling may and times all loved ones more than flirts with kitsch the tale commands attention',
#   'POS'),
#  ('palma spent hour setting fancy table and then served kraft macaroni and cheese',
#   'NEG'),
#  ('no ', 'NEG'),
#  ('admit hate like', 'NEG'),
#  ('kind sad that many people put much time and energy into this turkey',
#   'NEG'),
#  ('somewhere the middle the film compels demme experiments harvests few movie moment gems but the field roughage dominates',
#   'NEG'),
#  ('fun wispy wise and surprisingly inoffensive for film about teen love with his stepmom',
#   'POS'),
#  ('the rich performances friel and especially williams american actress who becomes fully english round out the square edges',
#   'POS'),
#  ('what saves and makes one the better video game based flicks that the film acknowledges upfront that the plot makes sense such that the lack linearity the point emotional and moral departure for protagonist alice',
#   'POS'),
#  ('several steven soderbergh earlier films were hailed the works artist',
#   'POS'),
#  ('simultaneously heartbreakingly beautiful and exquisitely sad', 'NEG'),
#  ('times bit melodramatic and even little dated lrb depending upon where you live rrb ignorant fairies still quite good natured and not bad way spend hour two',
#   'POS'),
#  ('taken outside the context the current political climate lrb see terrorists are more evil than ever rrb ',
#   'NEG'),
#  ('the exploitative clumsily staged violence overshadows everything including most the actors',
#   'POS'),
#  ('wildly entertaining scan evans career', 'POS'),
#  ('often silly and gross but rarely moronic some campus gross out films',
#   'NEG'),
#  ('fan film that for the uninitiated plays better video with the sound turned down',
#   'NEG'),
#  ('tells its story flat manner and leaves you with the impression that you should have gotten more out than you did',
#   'NEG'),
#  ('fairly solid not mention well edited that certainly does n t feel like film that strays past the two and half mark',
#   'POS'),
#  ('major waste generic', 'NEG'),
#  ('insular world', 'NEG'),
#  ('damon brings the proper conviction his role lrb jason bourne rrb ', 'POS'),
#  ('dogtown z boys evokes the blithe rebel fantasy with the kind insouciance embedded the sexy demise james dean',
#   'POS'),
#  ('for the rest sitting through dahmer two hours amounts little more than punishment',
#   'NEG'),
#  (' lrb the digital effects rrb reminded terry gilliam rudimentary old monty python cartoons which would cut out figures from drawings and photographs and paste them together',
#   'NEG'),
#  ('there disguising this one the worst films the summer', 'NEG'),
#  ('good naturedly cornball sequel', 'POS'),
#  ('bonanza wacky sight gags outlandish color schemes and corny visual puns that can appreciated equally abstract frank tashlin comedy and playful recapitulation the artist career',
#   'NEG'),
#  ('sometimes feel the film careens from one colorful event another without respite but sometimes must have seemed frida kahlo her life did too',
#   'NEG'),
#  ('may lack the pungent bite its title but enjoyable trifle nonetheless',
#   'POS'),
#  (' ve never bought from telemarketers but bought this movie', 'POS'),
#  ('screenwriter chris ver weil directing debut good natured and never dull but its virtues are small and easily overshadowed its predictability',
#   'NEG'),
#  ('you may think you have figured out the con and the players this debut film argentine director fabian bielinsky but while you were thinking someone made off with your wallet',
#   'NEG'),
#  ('would work much better one hour documentary', 'NEG'),
#  ('compelling pre wwii drama with vivid characters and warm moving message',
#   'POS'),
#  ('smug and convoluted action comedy that does n t allow earnest moment pass without reminding audiences that only movie',
#   'NEG'),
#  ('not saying that ice age does n t have some fairly pretty pictures but there not enough substance the story actually give them life',
#   'NEG'),
#  ('fragile framework upon which hang broad mildly fleshed out characters that seem have been conjured only minutes prior filming',
#   'NEG'),
#  ('affable but undernourished romantic comedy that fails match the freshness the actress producer and writer previous collaboration miss congeniality',
#   'NEG'),
#  ('not about scares but mood which ominous pervasive and unknown threat lurks just below the proceedings and adds almost constant mindset suspense',
#   'POS'),
#  ('pale xerox other better crime movies', 'NEG'),
#  ('scherfig who has had successful career tackles more than she can handle',
#   'NEG'),
#  ('while this film has list cast and some strong supporting players the tale like its central figure vivi just little bit hard love',
#   'NEG'),
#  ('overall tomfoolery like this matter taste', 'NEG'),
#  ('canada arctic light shines bright this frozen tundra soap opera that breathes extraordinary life into the private existence the inuit people',
#   'POS'),
#  ('terrific movie fact the best recent memory', 'POS'),
#  ('worth catching for griffiths warm and winning central performance', 'POS'),
#  ('the material slight and admittedly manipulative jacquot preserves tosca intoxicating ardor through his use the camera',
#   'POS'),
#  ('beautifully reclaiming the story carmen and recreating african idiom',
#   'POS'),
#  ('what embarrassment', 'NEG'),
#  ('film epic scale with intimate feeling saga the ups and downs friendships',
#   'POS'),
#  ('despite its hawaiian setting the science fiction trimmings and some moments rowdy slapstick the basic plot lilo could have been pulled from tear stained vintage shirley temple script',
#   'NEG'),
#  ('the ya ya have many secrets and one the books are better', 'NEG'),
#  ('ponderous plodding soap opera disguised feature film', 'NEG'),
#  (' stylistically the movie disaster', 'NEG'),
#  ('this new movie version the alexandre dumas classic the stuff high romance brought off with considerable wit',
#   'POS'),
#  ('when movie asks you feel sorry for mick jagger sex life already has one strike against',
#   'NEG'),
#  ('the symbols float like butterflies and the spinning styx sting like bees',
#   'NEG'),
#  ('the filmmakers post camp comprehension what made old time movies good bad that makes eight legged freaks perfectly entertaining summer diversion',
#   'POS'),
#  ('every moment crackles with tension and the end the flick you re the edge your seat',
#   'POS'),
#  ('maybe thomas wolfe was right you n t home again', 'NEG'),
#  ('underachieves only not taking the shakespeare parallels quite far enough',
#   'NEG'),
#  ('smart and funny albeit sometimes superficial cautionary tale technology search artist',
#   'POS'),
#  (' lrb watts rrb lend credibility this strange scenario and her presence succeeds making believe',
#   'POS'),
#  ('you can read the subtitles lrb the opera sung italian rrb and you like masterpiece theatre type costumes you ll enjoy this movie',
#   'POS'),
#  ('you could love safe conduct lrb laissez passer rrb for being subtitled french movie that minutes long',
#   'NEG'),
#  ('simple poignant and leavened with humor film that affirms the nourishing aspects love and companionship',
#   'POS'),
#  (' its solemn pretension prevents from sharing the awe which holds itself',
#   'NEG'),
#  ('nicely combines the enigmatic features memento with the hallucinatory drug culture requiem for dream',
#   'POS'),
#  ('manages please its intended audience children without placing their parents coma like state',
#   'POS'),
#  ('awkward hybrid genres that just does n t work', 'NEG'),
#  ('stuffy full itself morally ambiguous and nothing shout about', 'NEG'),
#  ('oozes condescension from every pore', 'NEG'),
#  ('translating complex characters from novels the big screen impossible task but they are true the essence what ya ya',
#   'POS'),
#  ('its own floundering way gets you', 'POS'),
#  ('disappointing comparison other recent war movies any other john woo flick for that matter',
#   'NEG'),
#  ('exactly what its title implies lusty boisterous and utterly charming',
#   'POS'),
#  ('bright pristine style and bold colors make much fun reading oversized picture book before bedtime',
#   'POS'),
#  ('movie loved first sight and even more important love remembrance', 'POS'),
#  ('brings awareness issue often overlooked women depression', 'NEG'),
#  ('feels slight were extended short albeit one made the smartest kids class',
#   'NEG'),
#  ('initially gripping eventually cloying pow drama', 'POS'),
#  ('mess', 'NEG'),
#  ('lillard and cardellini earn their scooby snacks but not anyone else',
#   'NEG'),
#  ('rare for any movie subtle and touching the son room', 'POS'),
#  ('too many scenarios which the hero might have opportunity triumphantly sermonize and too few that allow wonder for ourselves things will turn out okay',
#   'NEG'),
#  ('life affirming and heartbreaking sweet without the decay factor funny and sad',
#   'POS'),
#  ('any film that does n t even passing mention political prisoners poverty and the boat loads people who try escape the country less documentary and more propaganda way valentine sealed with kiss',
#   'NEG'),
#  ('average coming of age tale elevated the wholesome twist pesky mother interfering during her son discovery his homosexuality',
#   'NEG'),
#  ('with little visible talent and energy colin hanks bad need major acting lessons and maybe little coffee',
#   'NEG'),
#  ('the skirmishes for power waged among victims and predators settle into undistinguished rhythm artificial suspense',
#   'NEG'),
#  ('that fun for kids any age', 'POS'),
#  ('tired predictable bordering offensive waste time money and celluloid',
#   'NEG'),
#  ('this more fascinating being real than anything seen jerry springer', 'POS'),
#  ('none this very original and n t particularly funny', 'NEG'),
#  ('bernal and', 'NEG'),
#  ('one senses world traveler and his earlier film that freundlich bears grievous but obscure complaint against fathers and circles obsessively without making contact',
#   'NEG'),
#  (' weak and ineffective ghost story without conclusion pay off', 'NEG'),
#  ('this the kind subject matter that could easily have been fumbled lesser filmmaker but ayres makes the right choices every turn',
#   'POS'),
#  ('the worst film the year', 'NEG'),
#  ('there nothing interesting unfaithful whatsoever', 'NEG'),
#  ('unfortunately that precisely what arthur dong family fundamentals does',
#   'NEG'),
#  ('has way seeping into your consciousness with lingering questions about what the film really getting',
#   'POS'),
#  ('completely creatively stillborn and executed manner that not sure could single iota worse soulless hunk exploitative garbage',
#   'NEG'),
#  ('confessions may not straightforward bio nor does offer much the way barris motivations but the film oddly fascinating depiction architect pop culture',
#   'POS'),
#  ('too bad nothing else', 'NEG'),
#  ('sometimes need comforting fantasies about mental illness also need movies like tim mccann revolution no ',
#   'POS'),
#  ('domestic melodrama with weak dialogue and biopic cliches', 'NEG'),
#  ('philosophically intellectually and logistically mess', 'NEG'),
#  ('had dream that smart comedy would come along rescue from summer teen driven toilet humor codswallop and its name was earnest',
#   'POS'),
#  ('meeting even exceeding expectations the best sequel since the empire strikes back majestic achievement epic astonishing grandeur and surprising emotional depth',
#   'POS'),
#  ('exhilarating funny and fun', 'POS'),
#  ('the wonderful combination the sweetness and the extraordinary technical accomplishments the first film are maintained but its overall impact falls little flat with storyline that never quite delivers the original magic',
#   'NEG'),
#  ('the characters are paper thin and their personalities undergo radical changes when suits the script',
#   'NEG'),
#  ('the formula familiar but enjoyable', 'POS'),
#  ('the movie gloomy atmosphere fascinating though even the movie itself does n t stand ghost chance',
#   'NEG'),
#  ('only were well funnier', 'NEG'),
#  ('zellweger whiny pouty lipped poof faced and spindly attempt playing ingenue makes her nomination best actress even more',
#   'NEG'),
#  ('true pleasure', 'POS'),
#  ('the film maudlin focus the young woman infirmity and her naive dreams play like the worst kind hollywood heart string plucking',
#   'NEG'),
#  ('troll the cult section your local video store for the real deal', 'NEG'),
#  ('mike white deft combination serious subject matter and dark funny humor make the good girl film worth watching',
#   'POS'),
#  ('the road paved with good intentions leads the video store', 'POS'),
#  ('soderbergh seems capable only delivering artfully lighted earnest inquiries that lack the kind genuine depth that would make them redeemable',
#   'NEG'),
#  ('plods along minus the twisted humor and eye popping visuals that have made miike cult hero',
#   'NEG'),
#  ('maelstrom deliberately unsteady mixture stylistic elements', 'NEG'),
#  ('director david jacobson gives dahmer consideration that the murderer never game his victims',
#   'NEG'),
#  ('aside from the fact that the film idiotically uses the website feardotcom com the improperly hammy performance from poor stephen rea the film gets added disdain for the fact that nearly impossible look understand',
#   'NEG'),
#  ('might one those vanity projects which renowned filmmaker attempts show off his talent surrounding himself with untalented people',
#   'NEG'),
#  ('another best the year selection', 'POS'),
#  ('the not too distant future movies like ghost ship will used analgesic balm for overstimulated minds',
#   'NEG'),
#  ('the wake saving private ryan black hawk down and were soldiers you are likely heartily sick mayhem cage war weary marine',
#   'NEG'),
#  ('raimi crafted complicated hero who welcome relief from the usual two dimensional offerings',
#   'POS'),
#  ('times better than this', 'NEG'),
#  ('like drive by', 'NEG'),
#  ('the notion deleting emotion from people even advanced prozac nation insanely dysfunctional that the rampantly designed equilibrium becomes concept doofus',
#   'NEG'),
#  ('can viewed pure composition and form film music', 'POS'),
#  ('what makes the movie work admittedly limited extent the commitment two genuinely engaging performers',
#   'NEG'),
#  ('take nothing seriously and enjoy the ride', 'POS'),
#  ('live action cartoon fast moving and cheerfully simplistic minutes exaggerated action put together with the preteen boy mind',
#   'POS'),
#  ('impressive hybrid', 'POS'),
#  ('one those staggeringly well produced joylessly extravagant pictures that keep whooshing you from one visual marvel the next hastily emptily',
#   'NEG'),
#  ('warren stumbles search all the emotions and life experiences neglected over the years',
#   'NEG'),
#  ('ripper yarn and for one enjoyed the thrill the chill', 'POS'),
#  ('suspect this the kind production that would have been funnier the director had released the outtakes theatrically and used the film bonus feature the dvd',
#   'NEG'),
#  ('does n t deliver great story nor the action gripping past seagal films',
#   'NEG'),
#  ('villainous vampires are your cup blood blade definitely cut above the rest',
#   'POS'),
#  ('but entertaining inferior level', 'POS'),
#  ('check your brain and your secret agent decoder ring the door because you n t want think too much about what going',
#   'NEG'),
#  ('diverse and astonishingly articulate cast palestinian and israeli children',
#   'POS'),
#  ('one the best films the year with its exquisite acting inventive screenplay mesmerizing music and many inimitable scenes tenderness loss discontent and yearning',
#   'POS'),
#  ('ayurveda can help return sane regimen eating sleeping and stress reducing contemplation clearly good thing',
#   'POS'),
#  ('the filmmakers are playing the big boys new york and l a that end they mock the kind folks they n t understand ones they figure the power lunchers n t care understand either',
#   'NEG'),
#  ('refreshing see romance this smart', 'POS'),
#  ('impossible may sound this film heart even more embracing than monty only because accepts nasty behavior and severe flaws part the human condition',
#   'POS'),
#  ('easily the most thoughtful fictional examination the root causes anti semitism ever seen screen',
#   'POS'),
#  ('the master disguise may have made great saturday night live sketch but great movie not',
#   'NEG'),
#  ('works its magic with such exuberance and passion that the film length becomes part its fun',
#   'POS'),
#  ('may cause you bite your tongue keep from laughing the ridiculous dialog the oh so convenient plot twists',
#   'NEG'),
#  ('poignant comedy that offers food for thought', 'POS'),
#  ('many things stoner midnight flick sci fi deconstruction gay fantasia but above all love story sanguine its title',
#   'POS'),
#  ('very well meaning movie and will stand future years eloquent memorial the world trade center tragedy',
#   'POS'),
#  ('howard and his co stars all give committed performances but they re often undone howard self conscious attempts find literary filmmaking style match his subject',
#   'NEG'),
#  ('skip the film and buy the philip glass soundtrack', 'NEG'),
#  ('only masochistic moviegoers need apply', 'NEG'),
#  ('one funny popcorn flick', 'POS'),
#  ('none this sounds promising and indeed the first half sorority boys appalling any comedy ever spill from projector lens',
#   'NEG'),
#  ('about irrational unexplainable life and seems real because does not attempt filter out the complexity',
#   'POS'),
#  ('the dangerous lives altar boys has flaws but also has humor and heart and very talented young actors',
#   'POS'),
#  ('hard imagine acting that could any flatter', 'NEG'),
#  ('and n t avert our eyes for moment', 'POS'),
#  ('its worst the movie pretty diverting the pity that rarely achieves its best',
#   'NEG'),
#  ('this mistaken identity picture film culture referential that the final product ghost',
#   'NEG'),
#  ('but that they are doing thought provoking', 'POS'),
#  ('captures that perverse element the kafkaesque where identity overnight robbed and replaced with persecuted other',
#   'POS'),
#  ('the ending does n t work but most the movie works well almost recommending anyway maybe not everybody but certainly people with curiosity about how movie can very right and then step wrong',
#   'NEG'),
# ...
#   'POS'),
#  ('the sweetest thing romantic comedy with outrageous tendencies may mess lot ways',
#   'NEG'),
#  (' interesting slice history', 'POS'),
#  ('the execution pedestrian that the most positive comment can make that rob schneider actually turns pretty convincing performance prissy teenage girl',
#   'NEG'),
#  ('even you re elvis person you n t find anything get excited about this dvd',
#   'NEG'),
#  ('more than simply portrait early extreme sports this peek into the s skateboard revolution skateboard film social anthropology ',
#   'NEG'),
#  ('miyazaki has created such vibrant colorful world almost impossible not swept away the sheer beauty his images',
#   'POS'),
#  ('these guys seem great knock back beer with but they re simply not funny performers',
#   'NEG'),
#  ('becomes bit mishmash tearjerker that does n t and thriller that n t',
#   'NEG'),
#  ('scott delivers terrific performance this fascinating portrait modern lothario',
#   'POS'),
#  ('delightful minor pastry movie', 'POS'),
#  ('indeed the more outrageous bits achieve shock you into laughter intensity almost dadaist proportions',
#   'POS'),
#  ('reminiscent alfred hitchcock thrillers most the scary parts signs occur while waiting for things happen',
#   'POS'),
#  ('the film fits into genre that has been overexposed redolent thousand cliches and yet remains uniquely itself vibrant with originality',
#   'POS'),
#  ('how about starting with more original story instead just slapping extreme humor and gross out gags top the same old crap',
#   'NEG'),
#  ('affirms the gifts all involved starting with spielberg and going right through the ranks the players on camera and off that brings together',
#   'POS'),
#  (' lrb green rrb the comedy equivalent saddam hussein and just about ready the u n and ask permission for preemptive strike',
#   'NEG'),
#  ('these characters become wearisome', 'NEG'),
#  ('the audacity view one shakespeare better known tragedies dark comedy itself deserving discussion',
#   'NEG'),
#  ('settled into world war memories found myself strangely moved even the corniest and most hackneyed contrivances',
#   'POS'),
#  ('sort in between and works', 'POS'),
#  ('mimetic approximation better films', 'NEG'),
#  ('film that will enthrall the whole family', 'POS'),
#  ('lux now her eighties does great combination act narrator jewish grandmother and subject taking through film that part biography part entertainment and part history',
#   'POS'),
#  ('ramsay succeeds primarily with her typical blend unsettling atmospherics delivering series abrasive stylized sequences that burn themselves upon the viewer memory',
#   'POS'),
#  ('its best festival cannes bubbles with the excitement the festival cannes',
#   'NEG'),
#  ('any intellectual arguments being made about the nature god are framed drama clumsy there real danger less sophisticated audiences will mistake for endorsement the very things that bean abhors',
#   'NEG'),
#  ('the actors are fantastic', 'POS'),
#  ('what ensues are much blood splattering mass drug induced bowel evacuations and none too funny commentary the cultural distinctions between americans and brits',
#   'NEG'),
#  ('the large frame imax camera lends itself beautifully filming the teeming life the reefs making this gorgeous film must for everyone from junior scientists grown up fish lovers',
#   'POS'),
#  ('turns fanciful grisly and engagingly quixotic', 'POS'),
#  ('alas another breathless movie about same', 'NEG'),
#  ('venturesome beautifully realized psychological mood piece that reveals its first time feature director understanding the expressive power the camera',
#   'POS'),
#  ('the film fails fulfill its own ambitious goals nonetheless sustains interest during the long build up expository material',
#   'POS'),
#  ('best indie the year far', 'POS'),
#  ('unfortunately neither sendak nor the directors are particularly engaging articulate',
#   'NEG'),
#  ('bravado kathy', 'POS'),
#  ('overall interesting documentary but not very imaxy', 'NEG'),
#  ('gives intriguing twist the french coming of age genre', 'POS'),
#  ('this story that zings all the way through with originality humour and pathos',
#   'POS'),
#  ('else doggie winks', 'NEG'),
#  ('well crafted film that all the more remarkable because achieves its emotional power and moments revelation with restraint and delicate ambiguity',
#   'POS'),
#  ('helmer hudlin tries make hip comedy but his dependence slapstick defeats the possibility creating more darkly edged tome',
#   'NEG'),
#  ('the work filmmaker who has secrets buried the heart his story and knows how take time revealing them',
#   'POS'),
#  (' lrb take care cat rrb honestly nice little film that takes examination young adult life urban south korea through the hearts and minds the five principals',
#   'POS'),
#  ('stuffed the brim with ideas american instigator michael moore film rambling examination american gun culture that uses his usual modus operandi crucifixion through juxtaposition',
#   'POS'),
#  (' minute travesty unparalleled proportions writer director parker seems out his way turn the legendary wit classic mistaken identity farce into brutally labored and unfunny hokum',
#   'NEG'),
#  ('classic fairy tale that perfectly captures the wonders and worries childhood way that few movies have ever approached',
#   'POS'),
#  ('what vast enterprise has been marshaled the service such minute idea',
#   'NEG'),
#  ('blade estrogen free movies get you might want leave your date behind for this one she gonna make you feel like you owe her big time',
#   'NEG'),
#  ('not fan the phrase life affirming because usually means schmaltzy but real women have curves truly life affirming',
#   'POS'),
#  ('audiard successfully maintains suspense different levels throughout film that both gripping and compelling',
#   'POS'),
#  ('try you might resist you ve got place your heart for smokey robinson this movie will worm its way there',
#   'POS'),
#  ('the santa clause proves itself more streamlined and thought out encounter than the original could ever have hoped',
#   'POS'),
#  ('the screenplay co written director imogen kimmel lacks the wit necessary fully exploit the comic elements the premise making the proceedings more bizarre than actually amusing',
#   'NEG'),
#  ('tour force drama about the astonishingly pivotal role imagination the soulful development two rowdy teenagers',
#   'POS'),
#  ('call this one eventual cult classic would understatement and woe the horror fan who opts overlook this goofily endearing and well lensed gorefest',
#   'POS'),
#  ('the film may not hit hard some the better drug related pictures but still manages get few punches',
#   'NEG'),
#  ('all stitched together with energy intelligence and verve enhanced surplus vintage archive footage',
#   'POS'),
#  ('the film feels uncomfortably real its language and locations bearing the unmistakable stamp authority',
#   'POS'),
#  ('lush and beautifully photographed lrb somebody suggested the stills might make nice coffee table book rrb but ultimately you ll leave the theater wondering why these people mattered',
#   'NEG'),
#  (' lrb cho face rrb amazing slapstick instrument creating scrapbook living mug shots',
#   'POS'),
#  ('punitively affirmational parable', 'NEG'),
#  ('the threat', 'NEG'),
#  ('worthless from its pseudo rock video opening the idiocy its last frames',
#   'NEG'),
#  ('entertaining but like shooting fish barrel', 'NEG'),
#  ('steers refreshingly clear the usual cliches', 'POS'),
#  ('soulless jumble ineptly assembled cliches and pabulum that plays like minute commercial for nba properties',
#   'NEG'),
#  ('they just have problems which are neither original nor are presented convincing way',
#   'NEG'),
#  ('nothing more than amiable but unfocused bagatelle that plays like loosely connected string acting workshop exercises',
#   'NEG'),
#  ('disturbing examination what appears the definition bad police shooting',
#   'NEG'),
#  ('bad such bizarre way that almost worth seeing only witness the crazy confluence purpose and taste',
#   'NEG'),
#  ('when one hears harry shearer going make his debut film director one would hope for the best',
#   'POS'),
#  ('pipe dream does have its charms', 'POS'),
#  ('too long and larded with exposition this somber cop drama ultimately feels flat the scruffy sands its titular community',
#   'NEG'),
#  ('the asylum material gripping are the scenes jia with his family', 'POS'),
#  ('never does lilo stitch reach the emotion timelessness disney great past even that more recent successes such mulan tarzan',
#   'NEG'),
#  ('effort watch this movie but eventually pays off and effective you stick with',
#   'POS'),
#  ('tries hard quirky and funny that the strain all too evident', 'NEG'),
#  ('examines its explosive subject matter nonjudgmentally wiseman previous studies inner city high schools hospitals courts and welfare centers',
#   'NEG'),
#  ('the whole thing fairly lame making par for the course for disney sequels',
#   'NEG'),
#  ('has its share arresting images', 'NEG'),
#  ('those you who n t believe santa claus probably also think that sequels can never capture the magic the original',
#   'NEG'),
#  ('dull simple minded and stereotypical tale drugs death and mind numbing indifference the inner city streets',
#   'NEG'),
#  ('the production design score and choreography are simply intoxicating',
#   'POS'),
#  ('there are plenty scenes frida that work but rarely they involve the title character herself',
#   'POS'),
#  ('may no brainer but least funny no brainer', 'POS'),
#  ('this seductive tease thriller gets the job done', 'POS'),
#  ('feels strangely hollow its emotional core', 'NEG'),
#  ('film director labute continues improve', 'POS'),
#  ('with flashbulb editing cover for the absence narrative continuity undisputed nearly incoherent excuse get the closing bout which time impossible care who wins',
#   'NEG'),
#  ('trying figure out the rules the country bear universe when are bears bears and when are they like humans only hairier would tax einstein brain',
#   'NEG'),
#  ('fast frantic and fun but also soon forgotten', 'NEG'),
#  ('silly loud and goofy', 'NEG'),
#  ('this harrowing journey into combat hell vividly captures the chaotic insanity and personal tragedies that are all too abundant when human hatred spews forth unchecked',
#   'NEG'),
#  (' funny the way that makes you ache with sadness lrb the way chekhov funny rrb profound without ever being self important warm without ever succumbing sentimentality',
#   'POS'),
#  ('good looking but relentlessly lowbrow outing plays like clueless does south fork',
#   'NEG'),
#  ('the film runs little longer than needs muccino either does n t notice when his story ends just n t tear himself away from the characters but smooth and professional',
#   'NEG'),
#  ('world traveler might not anywhere new arrive anyplace special but certainly honest attempt get something',
#   'POS'),
#  ('the drama discloses almost nothing', 'NEG'),
#  ('those who are only mildly curious fear will put sleep bewildered the artsy and often pointless visuals',
#   'NEG'),
#  ('you ll feel like you ate reeses without the peanut butter ', 'NEG'),
#  ('nearly hours the film way too indulgent', 'NEG'),
#  ('into how long this movie', 'NEG'),
#  ('salma goes native and she never been better this colorful bio pic mexican icon',
#   'POS'),
#  ('the film weighed down supporting characters who are either too goodly wise and knowing downright comically evil',
#   'NEG'),
#  ('many benjamins elements feel like they ve been patched from episode miami vice',
#   'NEG'),
#  ('daily struggles and simple pleasures usurp the preaching message that the time the credits roll across the pat ending warm fuzzy feeling prevails',
#   'POS'),
#  ('but the whole you re gonna like this movie', 'POS'),
#  ('there real visual charge the filmmaking and strong erotic spark the most crucial lip reading sequence',
#   'POS'),
#  ('often watchable though goofy and lurid blast costume drama set the late th century',
#   'POS'),
#  ('like the chilled breath oral storytelling frozen onto film', 'POS'),
#  ('too long and unfocused', 'NEG'),
#  ('sheridan painfully bad fourth rate jim carrey who does n t understand the difference between dumb fun and just plain dumb',
#   'NEG'),
#  ('demonstrates vivid imagination and impressive style that result some terrific setpieces',
#   'POS'),
#  ('jonah only so so the addition biblical message will either improve the film for you will lessen',
#   'NEG'),
#  ('cage makes unusual but pleasantly haunting debut behind the camera', 'POS'),
#  ('you ll end moved', 'POS'),
#  (' liotta put impossible spot because his character deceptions ultimately undo him and the believability the entire scenario',
#   'NEG'),
#  ('dreary indulgence', 'NEG'),
#  ('ms phoenix completely lacking charm and charisma and unable project either esther initial anomie her eventual awakening',
#   'NEG'),
#  ('this n t terrible film any means but also far from being realized work',
#   'NEG'),
#  ('the performances are immaculate with roussillon providing comic relief',
#   'POS'),
#  ('either fascinating study the relationship between mothers and their children disturbing story about sociopaths and their marks',
#   'NEG'),
#  ('those eternally devoted the insanity black will have intermittently good time',
#   'POS'),
#  ('rice never clearly defines his characters gives reason care about them',
#   'NEG'),
#  (' lrb rrb satisfying niblet', 'POS'),
#  ('yet another weepy southern bore athon', 'NEG'),
#  ('coming of age film', 'NEG'),
#  ('meatier deeper beginning and or ending would have easily tipped this film into the range very very strong',
#   'POS'),
#  ('the members manage pronounce kok exactly you think they might thus giving the cast ample opportunity use that term often possible',
#   'NEG'),
#  ('good documentary can make interesting subject you thought would leave you cold',
#   'POS'),
#  ('not awful some the recent hollywood trip tripe but far from groundbreaking endeavor',
#   'NEG'),
#  ('often cute film but either needs more substance fill the time some judicious editing',
#   'NEG'),
#  ('ambitious what', 'POS'),
#  ('chiller resolutely without chills', 'NEG'),
#  ('alternately hilarious and sad aggravating and soulful scathing and joyous',
#   'POS'),
#  ('touches smartly and wistfully number themes not least the notion that the marginal members society might benefit from helping hand and friendly kick the pants',
#   'POS'),
#  ('although the film boils down lightweight story about matchmaking the characters make italian for beginners worth the journey',
#   'POS'),
#  (' lrb garbus rrb discards the potential for pathological study exhuming instead the skewed melodrama the circumstantial situation',
#   'NEG'),
#  ('manages wholesome and subversive the same time', 'POS'),
#  ('robert john burke the monster horns and steals the show', 'POS'),
#  ('roman polanski autobiographical gesture redemption better than shindler list more than merely holocaust movie',
#   'POS'),
#  ('bad the operative word for bad company and n t mean that good way', 'NEG'),
#  ('mild meandering teen flick', 'NEG'),
#  ('harry potter and the chamber secrets deja all over again and while that cliche nothing could more appropriate',
#   'NEG'),
#  ('trapped n t score points for political correctness but may cause parents few sleepless hours sign its effectiveness',
#   'POS'),
#  ('waydowntown may not important movie even good one but provides nice change mindless pace collision with the hot oscar season currently underway',
#   'POS'),
#  ('skins has desolate air but eyre native american raised white parents manages infuse the rocky path sibling reconciliation with flashes warmth and gentle humor',
#   'POS'),
#  ('though pretends expose the life male hustlers exploitive without being insightful',
#   'NEG'),
#  ('manages both hugely entertaining and uplifting', 'POS'),
#  ('uncluttered resonant gem that relays its universal points without lectures confrontations',
#   'POS'),
#  ('awfully good achingly human picture', 'POS'),
#  ('the power shanghai ghetto documentary dana janklowicz mann and amir mann rests the voices men and women now their s who lived there the s',
#   'POS'),
#  ('yet another movie which presumes that high school social groups are war let alone conscious each other existence',
#   'NEG'),
#  ...]

# %% [markdown]
# ## 6. Model -  BoW Classifier

# %%
class BoWClassifier(nn.Module):
    def __init__(self, num_labels, vocab_size):
        super(BoWClassifier, self).__init__()
        
        ## Defining parameters for linear model
        self.linear = nn.Linear(vocab_size, num_labels)
    
    def forward(self, bow_vec):
        ## do the foward pass and implement non-linearity
        return F.log_softmax(self.linear(bow_vec))

# %%
def make_bow_vector(sentence, word_to_ix):
    vec = torch.zeros(len(word_to_ix))
    for word in sentence.split():
        vec[word_to_ix[word]] += 1
    return vec.view(1,-1)

# %%
def make_target(label, label_to_idx):
    return torch.LongTensor([label_to_idx[label]])

# %%
n=5118
sample_phrase=make_bow_vector(x_train[n],word_to_ix)
print(">> SENTENCE: {}".format(x_train[n]))
print(">> SENTIMENT: {}".format(y_train[n]))
print(">> INPUT SIZE: {}".format(sample_phrase.size()))
sample_phrase
# Out:
# >> SENTENCE: feeble comedy
# >> SENTIMENT: NEG
# >> INPUT SIZE: torch.Size([1, 17454])
#     0     0     0  ...      0     0     0
# [torch.FloatTensor of size 1x17454]

# %% [markdown]
# ## 7. Training

# %%
VOCAB_SIZE = len(word_to_ix)
NUM_LABELS = len(label_to_ix)

# %%
model = BoWClassifier(NUM_LABELS,VOCAB_SIZE)

# %%
for param in model.parameters():
    print(param)
# Out:
# Parameter containing:
# 1.00000e-03 *
# -6.8583  6.4013  2.0233  ...   2.2908  0.2709 -3.6443
#  6.1853  6.9782  1.0960  ...   7.3783 -1.8122  1.5992
# [torch.FloatTensor of size 2x17454]
#
# Parameter containing:
# 1.00000e-03 *
#   5.8047
#   0.0330
# [torch.FloatTensor of size 2]

# %%
loss_function = nn.CrossEntropyLoss()
learning_rate = 0.01
optimizer = optim.SGD(params = model.parameters(), lr = learning_rate)

# %%
iter = 0
for epoch in range(num_epochs):
    for (sent,label) in train_data:
        # Step 1 - clear the gradients
        model.zero_grad()
        optimizer.zero_grad()
        
        ## Step 2- Prepare input and label
        bow_vec = Variable(make_bow_vector(sent, word_to_ix))
        target = Variable(make_target(label, label_to_ix))
        
        # Step 3 - Run forward pass
        output = model(bow_vec)
        #print("Log probabilities - {}".format(log_probs))
        
        # Step 4 - Compute loss, gradients, update parameters
        loss = loss_function(output, target)
        loss.backward()
        optimizer.step()
        
#        iter+=1
#  
#
#        if iter % 100 == 0:
#            correct = 0
#            total = 0
#            for (sent,label) in valid_data:
#                bow_vec = Variable(make_bow_vector(sent, word_to_ix))
#                target = Variable(make_target(label, label_to_ix))
#                output = model(bow_vec)
#                _,predicted = torch.max(output.data,1)
#                total += target.size(0)
#                correct += (predicted == label).sum()
#            accuracy = 100 * correct/total
#            print('Iterations: {}. Loss: {}. Accuracy: {}'.format(iter,loss.data[0],accuracy))

# %%
n=8
bow_vec = Variable(make_bow_vector(valid_data[n][0], word_to_ix))
print("-"*20 + " INPUT "+"-"*20)
print("LABEL = {}".format(valid_data[n][1]))
print("SENTENCE = {}".format(valid_data[n][0]))
print("-"*20 + " PREDICTION "+"-"*20)
log_probs = model(bow_vec)
_,predicted = torch.max(log_probs.data,1)
print("PRED = {}".format(predicted[0]))
print("LOG_PROB = {}".format(log_probs))
print("PROBS = {}".format(F.softmax(log_probs)))
# Out:
# -------------------- INPUT --------------------
# LABEL = NEG
# SENTENCE = all all reign fire will good lrb successful rrb rental
# -------------------- PREDICTION --------------------
# PRED = 0
# LOG_PROB = Variable containing:
# -0.4364 -1.0395
# [torch.FloatTensor of size 1x2]
#
# PROBS = Variable containing:
#  0.6464  0.3536
# [torch.FloatTensor of size 1x2]

# %% [markdown]
# ## References:
# - https://github.com/ilkarman/DeepLearningFrameworks/blob/lstm/LSTM_PyTorch_IMDB.ipynb
# - https://www.kaggle.com/himako/lb-0-424-naive-lstm-model-and-glove-embeddings
# - https://github.com/vanzytay/pytorch_sentiment_rnn
